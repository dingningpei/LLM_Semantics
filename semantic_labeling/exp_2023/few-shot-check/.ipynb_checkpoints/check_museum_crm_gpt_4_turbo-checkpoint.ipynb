# %%
import re

# Read the file content
with open('/root/autodl-tmp/semantic_labeling/exp_2023/few-shot-results/museum_crm_gpt_4_turbo/13.txt', 'r') as file:
    content = file.read()

# Use regex to find all <Step2> sections
step1_sections = re.findall(r'<Step1>(.*?)</Step1>', content, re.DOTALL)

# Store the extracted sections in a list
step1_list = [section.strip() for section in step1_sections]

# Print the list to verify
print(step1_list)
# Out:
# ["[['crm:E35_Title1', 'rdfs:label', 'title'],\n['crm:E82_Actor_Appellation1', 'rdfs:label', 'name'],\n['crm:E74_Group1', 'rdfs:label', 'nationality'],\n['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'],\n['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate']]", "[['crm:E35_Title1', 'rdfs:label', 'title'],\n['crm:E82_Actor_Appellation1', 'rdfs:label', 'name'],\n['crm:E74_Group1', 'rdfs:label', 'nationality'],\n['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'],\n['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate']]", "[['crm:E35_Title1', 'rdfs:label', 'title'],\n['crm:E38_Image1', 'karma:classLink', 'photo'],\n['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions'],\n['crm:E55_Type1', 'rdfs:label', 'technique'],\n['crm:E8_Acquisition1', 'crm:P3_has_note', 'credittext'],\n['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'artyear'],\n['crm:E22_Man-Made_Object1', 'karma:classLink', 'link'],\n['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'artdesc'],\n['crm:E82_Actor_Appellation1', 'rdfs:label', 'artist'],\n['crm:E74_Group1', 'rdfs:label', 'nationality'],\n['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'artistBirth'],\n['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'artistDeath']]", "[['crm:E40_Legal_Body1', 'karma:classLink', 'collectionURL'],\n['crm:E34_Inscription1', 'crm:P3_has_note', 'inscription'],\n['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'description'],\n['crm:E35_Title1', 'rdfs:label', 'title'],\n['crm:E78_Collection1', 'rdfs:label', 'collectionName'],\n['crm:E82_Actor_Appellation1', 'rdfs:label', 'artist'],\n['crm:E8_Acquisition1', 'crm:P3_has_note', 'credit'],\n['crm:E57_Material1', 'rdfs:label', 'materials'],\n['crm:E38_Image1', 'karma:classLink', 'imageURL'],\n['crm:E53_Place1', 'crm:P3_has_note', 'placeAndDataMade'],\n['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions']]", "[['crm:E55_Type1', 'rdfs:label', 'category'],\n['crm:E35_Title1', 'rdfs:label', 'title'],\n['crm:E82_Actor_Appellation1', 'rdfs:label', 'maker'],\n['crm:E74_Group1', 'rdfs:label', 'makerBioCountry'],\n['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'],\n['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate'],\n['crm:E39_Actor1', 'rdfs:label', 'collector'],\n['crm:E53_Place1', 'rdfs:label', 'placeMade'],\n['crm:E57_Material1', 'rdfs:label', 'materials'],\n['crm:E54_Dimension1', 'crm:P3_has_note', 'measurements'],\n['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'description'],\n['crm:E8_Acquisition1', 'crm:P3_has_note', 'creditLine'],\n['crm:E40_Legal_Body1', 'rdfs:label', 'owner']]", "[['crm:E35_Title1', 'rdfs:label', 'title'],\n['crm:E33_Linguistic_Object3', 'karma:classLink', 'sourceURL'],\n['crm:E38_Image1', 'karma:classLink', 'imageURL'],\n['crm:E82_Actor_Appellation2', 'rdfs:label', 'artist'],\n['crm:E74_Group2', 'rdfs:label', 'nationality'],\n['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'],\n['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate'],\n['crm:E52_Time-Span3', 'crm:P82_at_some_time_within', 'creationDate'],\n['crm:E55_Type2', 'rdfs:label', 'materials'],\n['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions'],\n['crm:E8_Acquisition1', 'crm:P3_has_note', 'creditLine'],\n['crm:E33_Linguistic_Object1', 'crm:P3_has_note', 'galleryLabel'],\n['crm:E8_Acquisition1', 'crm:P3_has_note', 'provenance']]", "[['crm:E82_Actor_Appellation1', 'rdfs:label', 'artistName'],\n['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'],\n['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate'],\n['crm:E55_Type3', 'rdfs:label', 'subtypeOfArt'],\n['crm:E55_Type1', 'rdfs:label', 'typeOfArt'],\n['crm:E35_Title1', 'rdfs:label', 'title'],\n['crm:E52_Time-Span3', 'crm:P82_at_some_time_within', 'dateMade'],\n['crm:E8_Acquisition1', 'crm:P3_has_note', 'credit'],\n['crm:E33_Linguistic_Object1', 'crm:P3_has_note', 'inscription'],\n['crm:E38_Image1', 'karma:classLink', 'picURL'],\n['crm:E54_Dimension1',  ...

# %%
import json

def load_json(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)
def normalize_semantics(semantics):
    # 提取并返回去掉编号的部分
    return [tuple(item[0].rsplit('-', 1)[0] + '-' + item[0].split('-')[-1] for item in triple) for triple in semantics]
def calculate_precision_recall(gold_semantics, predicted_semantics):
    # 先归一化语义三元组
    gold_set = set(normalize_semantics(gold_semantics))
    predicted_set = set(normalize_semantics(predicted_semantics))

    # 计算真阳性、假阳性和假阴性
    true_positives = len(gold_set.intersection(predicted_set))
    false_positives = len(predicted_set - gold_set)
    false_negatives = len(gold_set - predicted_set)
    print(f"Wrong: {str(predicted_set - gold_set)}")

    # 计算精确度和召回率
    if len(predicted_set) == 1 and len(predicted_set) == 0 and len(gold_set) == 0:
        precision = 1
        recall = 1
    else:
        precision = true_positives / (len(predicted_set)) if (true_positives + false_positives) > 0 else 0
        recall = true_positives / len(gold_set) if (true_positives + false_negatives) > 0 else 0
    return precision, recall

# %%
gold_list = [
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s03-ima-artists-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s18-s-indianapolis-artists-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s17-s-houston-museum-of-fine-arts-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s10-s-18-artworks-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s27-wildlife-art-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s04-ima-artworks-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s24-s-oakland-museum-paintings-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s19-s-indianapolis-artworks-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s20-s-lacma-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s11-s-19-artists-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s28-gilcrease-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s15-s-detroit-institute-of-art-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s23-s-norton-simon-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s13-s-art-institute-of-chicago-model.json"
]
pre = []
rec = []

# %%
for i, j in enumerate(gold_list):  
    gold_semantics = load_json(j)['semantic_triples']
    predicted_semantics = [i.replace('\'', '').split(", ") for i in step1_list[i][2:-2].split("],\n[")]
    print(gold_semantics)
    print(predicted_semantics)
    precision, recall = calculate_precision_recall(gold_semantics, predicted_semantics)
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    pre.append(precision)
    rec.append(recall)
print(f"Mean Precision: {sum(pre) / len(pre)}")
print(f"Mean Recall: {sum(rec) / len(rec)}")
# Out:
# [['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E82_Actor_Appellation1', 'rdfs:label', 'name'], ['crm:E74_Group1', 'rdfs:label', 'nationality'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'], ['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate']]
# [['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E82_Actor_Appellation1', 'rdfs:label', 'name'], ['crm:E74_Group1', 'rdfs:label', 'nationality'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'], ['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate']]
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# [['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E82_Actor_Appellation1', 'rdfs:label', 'name'], ['crm:E74_Group1', 'rdfs:label', 'nationality'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'], ['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate']]
# [['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E82_Actor_Appellation1', 'rdfs:label', 'name'], ['crm:E74_Group1', 'rdfs:label', 'nationality'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'], ['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate']]
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# [['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E38_Image1', 'karma:classLink', 'photo'], ['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions'], ['crm:E55_Type1', 'rdfs:label', 'technique'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'credittext'], ['crm:E52_Time-Span3', 'crm:P82_at_some_time_within', 'artyear'], ['crm:E22_Man-Made_Object1', 'karma:classLink', 'link'], ['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'artdesc'], ['crm:E82_Actor_Appellation1', 'rdfs:label', 'artist'], ['crm:E74_Group1', 'rdfs:label', 'nationality'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'artistBirth'], ['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'artistDeath']]
# [['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E38_Image1', 'karma:classLink', 'photo'], ['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions'], ['crm:E55_Type1', 'rdfs:label', 'technique'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'credittext'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'artyear'], ['crm:E22_Man-Made_Object1', 'karma:classLink', 'link'], ['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'artdesc'], ['crm:E82_Actor_Appellation1', 'rdfs:label', 'artist'], ['crm:E74_Group1', 'rdfs:label', 'nationality'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'artistBirth'], ['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'artistDeath']]
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# [['crm:E78_Collection1', 'karma:classLink', 'collectionURL'], ['crm:E34_Inscription1', 'crm:P3_has_note', 'inscription'], ['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'description'], ['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E78_Collection1', 'rdfs:label', 'collectionName'], ['crm:E82_Actor_Appellation1', 'rdfs:label', 'artist'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'credit'], ['crm:E57_Material1', 'rdfs:label', 'materials'], ['crm:E38_Image1', 'karma:classLink', 'imageURL'], ['crm:E12_Production1', 'P3_has_note', 'placeAndDataMade'], ['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions']]
# [['crm:E40_Legal_Body1', 'karma:classLink', 'collectionURL'], ['crm:E34_Inscription1', 'crm:P3_has_note', 'inscription'], ['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'description'], ['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E78_Collection1', 'rdfs:label', 'collectionName'], ['crm:E82_Actor_Appellation1', 'rdfs:label', 'artist'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'credit'], ['crm:E57_Material1', 'rdfs:label', 'materials'], ['crm:E38_Image1', 'karma:classLink', 'imageURL'], ['crm:E53_Place1', 'crm:P3_has_note', 'placeAndDataMade'], ['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions']]
# Wrong: {('c-c', 'c-c', 'p-p')}
# Precision: 0.9
# Recall: 0.9
# [['crm:E55_Type1', 'rdfs:label', 'category'], ['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E82_Actor_Appellation1', 'rdfs:label', 'maker'], ['crm:E74_Group1', 'rdfs:label', 'makerBioCountry'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'], ['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate'], ['crm:E33_Linguistic_Object1', 'crm:P3_has_note', 'collector'], ['crm:E48_Place_Name1', 'rdfs:label', 'placeMade'], ['crm:E55_Type2', 'rdfs:label', 'materials'], ['crm:E54_Dimension1', 'crm:P3_has_note', 'measurements'], ['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'description'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'creditLine'], ['crm:E40_Legal_Body1', 'rdfs:label', 'owner'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'howAcquired']]
# [['crm:E55_Type1', 'rdfs:label', 'category'], ['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E82_Actor_Appellation1', 'rdfs:label', 'maker'], ['crm:E74_Group1', 'rdfs:label', 'makerBioCountry'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'], ['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate'], ['crm:E39_Actor1', 'rdfs:label', 'collector'], ['crm:E53_Place1', 'rdfs:label', 'placeMade'], ['crm:E57_Material1', 'rdfs:label', 'materials'], ['crm:E54_Dimension1', 'crm:P3_has_note', 'measurements'], ['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'description'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'creditLine'], ['crm:E40_Legal_Body1', 'rdfs:label', 'owner']]
# Wrong: set()
# Precision: 1.0
# Recall: 0.9
# [['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E22_Man-Made_Object1', 'karma:classLink', 'sourceURL'], ['crm:E38_Image1', 'karma:classLink', 'imageURL'], ['crm:E82_Actor_Appellation1', 'rdfs:label', 'artist'], ['crm:E74_Group1', 'rdfs:label', 'nationality'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'], ['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate'], ['crm:E52_Time-Span3', 'crm:P82_at_some_time_within', 'creationDate'], ['crm:E55_Type1', 'rdfs:label', 'materials'], ['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'creditLine'], ['crm:E33_Linguistic_Object1', 'crm:P3_has_note', 'galleryLabel'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'provenance']]
# [['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E33_Linguistic_Object3', 'karma:classLink', 'sourceURL'], ['crm:E38_Image1', 'karma:classLink', 'imageURL'], ['crm:E82_Actor_Appellation2', 'rdfs:label', 'artist'], ['crm:E74_Group2', 'rdfs:label', 'nationality'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'], ['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate'], ['crm:E52_Time-Span3', 'crm:P82_at_some_time_within', 'creationDate'], ['crm:E55_Type2', 'rdfs:label', 'materials'], ['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'creditLine'], ['crm:E33_Linguistic_Object1', 'crm:P3_has_note', 'galleryLabel'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'provenance']]
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# [['crm:E82_Actor_Appellation1', 'rdfs:label', 'artistName'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'], ['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate'], ['crm:E55_Type2', 'rdfs:label', 'subtypeOfArt'], ['crm:E55_Type1', 'rdfs:label', 'typeOfArt'], ['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E52_Time-Span3', 'crm:P82_at_some_time_within', 'dateMade'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'credit'], ['crm:E34_Inscription1', 'crm:P3_has_note', 'inscription'], ['crm:E38_Image1', 'karma:classLink', 'picURL'], ['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions']]
# [['crm:E82_Actor_Appellation1', 'rdfs:label', 'artistName'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'], ['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate'], ['crm:E55_Type3', 'rdfs:label', 'subtypeOfArt'], ['crm:E55_Type1', 'rdfs:label', 'typeOfArt'], ['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E52_Time-Span3', 'crm:P82_at_some_time_within', 'dateMade'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'credit'], ['crm:E33_Linguistic_Object1', 'crm:P3_has_note', 'inscription'], ['crm:E38_Image1', 'karma:classLink', 'picURL'], ['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions']]
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# [['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E22_Man-Made_Object1', 'karma:classLink', 'sourceURL'], ['crm:E38_Image1', 'karma:classLink', 'imageURL'], ['crm:E52_Time-Span3', 'crm:P82_at_some_time_within', 'creationDate'], ['crm:E57_Material1', 'rdfs:label', 'materials'], ['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'creditLine'], ['crm:E33_Linguistic_Object1', 'crm:P3_has_note', 'galleryLabel'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'provenance'], ['crm:E82_Actor_Appellation1', 'rdfs:label', 'artist'], ['crm:E74_Group1', 'rdfs:label', 'nationality'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'], ['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate']]
# [['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E31_Document1', 'karma:classLink', 'sourceURL'], ['crm:E38_Image1', 'karma:classLink', 'imageURL'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'creationDate'], ['crm:E57_Material1', 'rdfs:label', 'materials'], ['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'creditLine'], ['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'galleryLabel'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'provenance'], ['crm:E82_Actor_Appellation1', 'rdfs:label', 'artist'], ['crm:E74_Group1', 'rdfs:label', 'nationality'], ['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'birthDate'], ['crm:E52_Time-Span3', 'crm:P82_at_some_time_within', 'deathDate']]
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# [['crm:E82_Actor_Appellation1', 'rdfs:label', 'artistName'], ['crm:E48_Place_Name1', 'rdfs:label', 'residence'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'], ['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate'], ['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E52_Time-Span3', 'crm:P82_at_some_time_within', 'artworkDate'], ['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'artworkDetails'], ['crm:E21_Person1', 'crm:P3_has_note', 'artworkInFocus'], ['crm:E38_Image1', 'karma:classLink', 'imageURL']]
# [['crm:E82_Actor_Appellation1', 'rdfs:label', 'artistName'], ['crm:E53_Place', 'rdfs:label', 'residence'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'], ['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate'], ['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E52_Time-Span3', 'crm:P82_at_some_time_within', 'artworkDate'], ['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'artworkDetails'], ['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'artworkInFocus'], ['crm:E38_Image1', 'karma:classLink', 'imageURL']]
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# [['crm:E82_Actor_Appellation1', 'rdfs:label', 'artistName'], ['crm:E74_Group1', 'rdfs:label', 'nationality'], ['crm:E33_Linguistic_Object1', 'crm:P3_has_note', 'birthDataAndPlace'], ['crm:E39_Actor1', 'crm:P3_has_note', 'longBiography'], ['crm:E33_Linguistic_Object2', 'crm:P3_has_note', 'occupation']]
# [['crm:E82_Actor_Appellation1', 'rdfs:label', 'artistName'], ['crm:E74_Group1', 'rdfs:label', 'nationality'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'birthDataAndPlace'], ['crm:E39_Actor1', 'crm:P3_has_note', 'longBiography'], ['crm:E55_Type1', 'rdfs:label', 'occupation']]
# Wrong: {('c-c', 'r-r', 'o-o')}
# Precision: 0.8
# Recall: 0.8
# [['crm:E55_Type2', 'rdfs:label', 'culture'], ['crm:E82_Actor_Appellation1', 'rdfs:label', 'attribution'], ['crm:E55_Type1', 'rdfs:label', 'objectName'], ['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'dated'], ['crm:E55_Type3', 'rdfs:label', 'medium'], ['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions'], ['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'description']]
# [['crm:E74_Group1', 'rdfs:label', 'culture'], ['crm:E82_Actor_Appellation1', 'rdfs:label', 'attribution'], ['crm:E55_Type1', 'rdfs:label', 'objectName'], ['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E52_Time-Span3', 'crm:P82_at_some_time_within', 'dated'], ['crm:E55_Type2', 'rdfs:label', 'medium'], ['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions'], ['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'description']]
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# [['crm:E38_Image1', 'karma:classLink', 'imageURL'], ['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E52_Time-Span3', 'crm:P82_at_some_time_within', 'date'], ['crm:E55_Type2', 'rdfs:label', 'medium'], ['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions'], ['crm:E55_Type1', 'rdfs:label', 'classification'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'credit'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'provenance'], ['crm:E82_Actor_Appellation1', 'rdfs:label', 'name'], ['crm:E74_Group1', 'rdfs:label', 'nationality'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birth'], ['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'death']]
# [['crm:E38_Image1', 'karma:classLink', 'imageURL'], ['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E52_Time-Span', 'crm:P82_at_some_time_within', 'date'], ['crm:E55_Type', 'rdfs:label', 'medium'], ['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions'], ['crm:E55_Type', 'rdfs:label', 'classification'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'credit'], ['crm:E7_Activity1', 'crm:P3_has_note', 'provenance'], ['crm:E82_Actor_Appellation1', 'rdfs:label', 'name'], ['crm:E74_Group1', 'rdfs:label', 'nationality'], ['crm:E52_Time-Span', 'crm:P82_at_some_time_within', 'birth'], ['crm:E52_Time-Span', 'crm:P82_at_some_time_within', 'death']]
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# [['crm:E82_Actor_Appellation1', 'rdfs:label', 'artist'], ['crm:E74_Group1', 'rdfs:label', 'nationality'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'], ['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate'], ['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E52_Time-Span3', 'crm:P82_at_some_time_within', 'made'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'prov'], ['crm:E54_Dimension1', 'crm:P3_has_note', 'dim'], ['crm:E38_Image1', 'karma:classLink', 'imageURL']]
# [['crm:E82_Actor_Appellation1', 'rdfs:label', 'artist'], ['crm:E74_Group1', 'rdfs:label', 'nationality'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'], ['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate'], ['crm:E35_Title1', 'rdfs:label', 'title'], ['crm:E52_Time-Span3', 'crm:P82_at_some_time_within', 'made'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'prov'], ['crm:E54_Dimension1', 'crm:P3_has_note', 'dim'], ['crm:E38_Image1', 'karma:classLink', 'imageURL']]
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# [['crm:E22_Man-Made_Object1', 'karma:classLink', 'linktodata'], ['crm:E82_Actor_Appellation1', 'rdfs:label', 'artistName'], ['crm:E74_Group1', 'rdfs:label', 'nationality'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthYear'], ['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathYear'], ['crm:E35_Title1', 'rdfs:label', 'titleofartwork'], ['crm:E55_Type1', 'rdfs:label', 'typeofartwork'], ['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'credit'], ['crm:E38_Image1', 'karma:classLink', 'imageURL']]
# [['crm:E22_Man-Made_Object1', 'karma:classLink', 'linktodata'], ['crm:E82_Actor_Appellation1', 'rdfs:label', 'artistName'], ['crm:E74_Group1', 'rdfs:label', 'nationality'], ['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthYear'], ['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathYear'], ['crm:E35_Title1', 'rdfs:label', 'titleofartwork'], ['crm:E55_Type1', 'rdfs:label', 'typeofartwork'], ['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions'], ['crm:E8_Acquisition1', 'crm:P3_has_note', 'credit'], ['crm:E38_Image1', 'karma:classLink', 'imageURL']]
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# Mean Precision: 0.9785714285714286
# Mean Recall: 0.9714285714285715

# %%
import re

# Read the file content
with open('/root/autodl-tmp/semantic_labeling/exp_2023/few-shot-results/museum_crm_gpt_4_turbo/13.txt', 'r') as file:
    content = file.read()

# Use regex to find all <Step2> sections
step2_sections = re.findall(r'<Step2>(.*?)</Step2>', content, re.DOTALL)

# Store the extracted sections in a list
step2_list = [section.strip() for section in step2_sections]

# Print the list to verify
print(step2_list)
# Out:
# ["[['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'],\n['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'],\n['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'],\n['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'],\n['crm:E21_Person1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'],\n['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'],\n['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'],\n['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'],\n['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2']]", "[['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'],\n['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'],\n['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'],\n['crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'],\n['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'],\n['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'],\n['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'],\n['crm:E21_Person1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'],\n['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'],\n['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2']]", "[['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'],\n['crm:E22_Man-Made_Object1', 'crm:P65_shows_visual_item', 'crm:E38_Image1'],\n['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'],\n['crm:E22_Man-Made_Object1', 'crm:P32_used_general_technique', 'crm:E55_Type1'],\n['crm:E22_Man-Made_Object1', 'crm:P24i_changed_ownership_through', 'crm:E8_Acquisition1'],\n['crm:E22_Man-Made_Object1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'],\n['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'crm:E22_Man-Made_Object1'],\n['crm:E12_Production1', 'crm:P108i_was_produced_by', 'crm:E22_Man-Made_Object1'],\n['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'],\n['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'],\n['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'],\n['crm:E21_Person1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'],\n['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'],\n['crm:E69_Death1', 'crm:P100_was_death_of', 'crm:E21_Person1'],\n['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'],\n['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2']]", "[['crm:E38_Image1', 'crm:P138_represents', 'crm:E22_Man-Made_Object1'],\n['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'],\n['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E39_Actor1'],\n['crm:E39_Actor1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'],\n['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'],\n['crm:E22_Man-Made_Object1', 'crm:P24i_changed_ownership_through', 'crm:E8_Acquisition1'],\n['crm:E22_Man-Made_Object1', 'crm:P46_is_composed_of', 'crm:E57_Material1'],\n['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'],\n['crm:E12_Production1', 'crm:P7_took_place_at', 'crm:E53_Place1'],\n['crm:E53_Place1', 'crm:P1_is_identified_by', 'crm:E44_Place_Appellation1'],\n['crm:E12_Production1', 'crm:P70_documents', 'crm:E31_Document1'],\n['crm:E31_Document1', 'karma:classLink', 'crm:E34_Inscription1']]", "[['crm:E22_Man-Made_Object1', 'crm:P2_has_type', 'crm:E55_Type1'],\n['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'],\n['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'],\n['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'],\n['crm:E22_Man-Made_Object1', 'crm:P45_consists_of', 'crm:E57_Material1'],\n['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'],\n['crm:E12_Production1', 'crm:P7_took_place_at', 'crm:E53_Place1'],\n['crm:E ...

# %%
import json
def load_json(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)
        
def calculate_precision_recall(gold_semantics, predicted_semantics):
    gold_set = set(tuple(item) for item in gold_semantics)
    predicted_set = set(tuple(item) for item in predicted_semantics)
 
    # Calculate true positives, false positives, and false negatives
    true_positives = len(gold_set.intersection(predicted_set))
    false_positives = len(predicted_set - gold_set)
    false_negatives = len(gold_set - predicted_set)
    print(f"Wrong: {str(predicted_set - gold_set)}")

    # Calculate precision and recall
    if len(predicted_set) == 1 and len(predicted_set) == 0 and len(gold_set) == 0:
        precision = 1
        recall = 1
    else:
        precision = true_positives / (len(predicted_set)) if (true_positives + false_positives) > 0 else 0
        recall = true_positives / len(gold_set) if (true_positives + false_negatives) > 0 else 0
    return precision, recall

# %%
import networkx as nx

def prune_wrong(semantics, sm_type):
    G = nx.DiGraph()
    for item in semantics:
        try:
            s, p, o = item  # 尝试解包
            G.add_edge(s, o, predicate=p)
        except ValueError:
            print(f"Skipping invalid semantic: {item}")  # 打印跳过的项

    # Function to find leaf nodes in the graph
    Stop_flag = True
    while Stop_flag:
        Stop_flag = False
        nodes_to_check = list(G.nodes())  # Create a copy of the nodes
        for i in nodes_to_check:
            if G.out_degree(i) == 0 and G.in_degree(i) >= 1:
                if i not in sm_type:
                    print(f"prune: {i}")
                    G.remove_node(i)
                    Stop_flag = True

    updated_triples = [[s, G.edges[s, o]['predicate'], o] for s, o in G.edges()]
    return updated_triples

# %%
gold_list = [
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s03-ima-artists-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s18-s-indianapolis-artists-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s17-s-houston-museum-of-fine-arts-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s10-s-18-artworks-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s27-wildlife-art-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s04-ima-artworks-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s24-s-oakland-museum-paintings-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s19-s-indianapolis-artworks-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s20-s-lacma-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s11-s-19-artists-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s28-gilcrease-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s15-s-detroit-institute-of-art-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s23-s-norton-simon-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-crm/models_triples_json/s13-s-art-institute-of-chicago-model.json"
]

# %%
def convert_notation(semantics):
    if len(semantics) == 0:
        return semantics
    map_dict = {}
    for i, item in enumerate(semantics):
        if map_dict.get(item[0][:-1]) is None:
            map_dict[item[0][:-1]] = [item[0]]
        else:
            if item[0] not in map_dict[item[0][:-1]]:
                map_dict[item[0][:-1]].append(item[0])
        if map_dict.get(item[2][:-1]) is None:
            map_dict[item[2][:-1]] = [item[2]]
        else:
            if item[2] not in map_dict[item[2][:-1]]:
                map_dict[item[2][:-1]].append(item[2])
    convert_dict = {}
    for key, value in map_dict.items():
        for i, item in enumerate(value):
            if item[-1] != str(i+1):
                convert_dict[item] = item[:-1] + str(i+1)
    for i, item in enumerate(semantics):
        if convert_dict.get(item[0]) is not None:
            semantics[i][0] = convert_dict[item[0]]
        if convert_dict.get(item[2]) is not None:
            semantics[i][2] = convert_dict[item[2]]
    # print(map_dict)
    # print(convert_dict)
    return semantics

# %%
pre = []
rec = []
for i, j in enumerate(gold_list):  
    gold_semantics = load_json(j)['internal_link_triples']
    predicted_semantics = [i.replace("'", "").split(", ") for i in step2_list[i][2:-2].split("],\n[")]
    #Addded
    semantic_type = [i.replace("'", "").split(", ") for i in step1_list[i][2:-2].split("],\n[")]
    semantic_type = [i[0] for i in semantic_type]
    predicted_semantics = prune_wrong(predicted_semantics, semantic_type)
    gold_semantics = sorted(gold_semantics, key=lambda x: (x[0], x[2], x[1]))
    predicted_semantics = sorted(predicted_semantics, key=lambda x: (x[0], x[2], x[1]))
    gold_semantics = convert_notation(gold_semantics)
    predicted_semantics = convert_notation(predicted_semantics)
    print(gold_semantics)
    print(predicted_semantics)
    #Added
    precision, recall = calculate_precision_recall(gold_semantics, predicted_semantics)
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    pre.append(precision)
    rec.append(recall)
print(f"Mean Precision: {sum(pre) / len(pre)}")
print(f"Mean Recall: {sum(rec) / len(rec)}")
# Out:
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E21_Person1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2']]
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E21_Person1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2']]
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E21_Person1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2']]
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E21_Person1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2']]
# Wrong: {('crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1')}
# Precision: 0.9
# Recall: 1.0
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E12_Production1', 'crm:P32_used_general_technique', 'crm:E55_Type1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E21_Person1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'], ['crm:E22_Man-Made_Object1', 'crm:P24i_changed_ownership_through', 'crm:E8_Acquisition1'], ['crm:E38_Image1', 'crm:P138_represents', 'crm:E22_Man-Made_Object1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span3']]
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E12_Production1', 'crm:P108i_was_produced_by', 'crm:E22_Man-Made_Object1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E21_Person1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'crm:E22_Man-Made_Object1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E22_Man-Made_Object1', 'crm:P65_shows_visual_item', 'crm:E38_Image1'], ['crm:E22_Man-Made_Object1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'], ['crm:E22_Man-Made_Object1', 'crm:P32_used_general_technique', 'crm:E55_Type1'], ['crm:E22_Man-Made_Object1', 'crm:P24i_changed_ownership_through', 'crm:E8_Acquisition1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E69_Death1', 'crm:P100_was_death_of', 'crm:E21_Person1'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2']]
# Wrong: {('crm:E22_Man-Made_Object1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'), ('crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'crm:E22_Man-Made_Object1'), ('crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'), ('crm:E12_Production1', 'crm:P108i_was_produced_by', 'crm:E22_Man-Made_Object1'), ('crm:E69_Death1', 'crm:P100_was_death_of', 'crm:E21_Person1'), ('crm:E22_Man-Made_Object1', 'crm:P32_used_general_technique', 'crm:E55_Type1'), ('crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2'), ('crm:E22_Man-Made_Object1', 'crm:P65_shows_visual_item', 'crm:E38_Image1')}
# Precision: 0.5
# Recall: 0.5714285714285714
# prune: crm:E44_Place_Appellation1
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P65_shows_visual_item', 'crm:E34_Inscription1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'], ['crm:E22_Man-Made_Object1', 'crm:P45_consists_of', 'crm:E57_Material1'], ['crm:E22_Man-Made_Object1', 'crm:P46i_forms_part_of', 'crm:E78_Collection1'], ['crm:E22_Man-Made_Object1', 'crm:P24i_changed_ownership_through', 'crm:E8_Acquisition1'], ['crm:E38_Image1', 'crm:P138_represents', 'crm:E22_Man-Made_Object1']]
# [['crm:E12_Production1', 'crm:P70_documents', 'crm:E31_Document1'], ['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E39_Actor1'], ['crm:E12_Production1', 'crm:P7_took_place_at', 'crm:E53_Place1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'], ['crm:E22_Man-Made_Object1', 'crm:P46_is_composed_of', 'crm:E57_Material1'], ['crm:E22_Man-Made_Object1', 'crm:P24i_changed_ownership_through', 'crm:E8_Acquisition1'], ['crm:E31_Document1', 'karma:classLink', 'crm:E34_Inscription1'], ['crm:E38_Image1', 'crm:P138_represents', 'crm:E22_Man-Made_Object1'], ['crm:E39_Actor1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1']]
# Wrong: {('crm:E12_Production1', 'crm:P70_documents', 'crm:E31_Document1'), ('crm:E12_Production1', 'crm:P7_took_place_at', 'crm:E53_Place1'), ('crm:E31_Document1', 'karma:classLink', 'crm:E34_Inscription1'), ('crm:E39_Actor1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'), ('crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E39_Actor1'), ('crm:E22_Man-Made_Object1', 'crm:P46_is_composed_of', 'crm:E57_Material1')}
# Precision: 0.45454545454545453
# Recall: 0.5
# prune: crm:E52_Time-Span3
# [['crm:E12_Production1', 'crm:P108i_was_produced_by', 'crm:E21_Person1'], ['crm:E12_Production1', 'crm:P7_took_place_at', 'crm:E53_Place1'], ['crm:E12_Production1', 'crm:P32_used_general_technique', 'crm:E55_Type1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E21_Person1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E22_Man-Made_Object1', 'crm:P51_has_former_or_current_owner', 'crm:E40_Legal_Body1'], ['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'], ['crm:E22_Man-Made_Object1', 'crm:P2_has_type', 'crm:E55_Type2'], ['crm:E22_Man-Made_Object1', 'crm:P24i_changed_ownership_through', 'crm:E8_Acquisition1'], ['crm:E33_Linguistic_Object1', 'crm:P129_is_about', 'crm:E22_Man-Made_Object1'], ['crm:E53_Place1', 'crm:P87_is_identified_by', 'crm:E48_Place_Name1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2']]
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E12_Production1', 'crm:P7_took_place_at', 'crm:E53_Place1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E21_Person1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'], ['crm:E22_Man-Made_Object1', 'crm:P2_has_type', 'crm:E55_Type1'], ['crm:E22_Man-Made_Object1', 'crm:P45_consists_of', 'crm:E57_Material1'], ['crm:E39_Actor1', 'crm:P14i_performed', 'crm:E8_Acquisition1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2'], ['crm:E8_Acquisition1', 'crm:P24i_changed_ownership_through', 'crm:E40_Legal_Body1']]
# Wrong: {('crm:E22_Man-Made_Object1', 'crm:P45_consists_of', 'crm:E57_Material1'), ('crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'), ('crm:E22_Man-Made_Object1', 'crm:P2_has_type', 'crm:E55_Type1'), ('crm:E8_Acquisition1', 'crm:P24i_changed_ownership_through', 'crm:E40_Legal_Body1'), ('crm:E39_Actor1', 'crm:P14i_performed', 'crm:E8_Acquisition1')}
# Precision: 0.6666666666666666
# Recall: 0.5882352941176471
# prune: crm:E53_Place1
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E12_Production1', 'crm:P32_used_general_technique', 'crm:E55_Type1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E21_Person1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'], ['crm:E22_Man-Made_Object1', 'crm:P24i_changed_ownership_through', 'crm:E8_Acquisition1'], ['crm:E33_Linguistic_Object1', 'crm:P129_is_about', 'crm:E22_Man-Made_Object1'], ['crm:E38_Image1', 'crm:P138_represents', 'crm:E22_Man-Made_Object1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span3']]
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E12_Production1', 'crm:P32_used_general_technique', 'crm:E55_Type1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E21_Person1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'], ['crm:E22_Man-Made_Object1', 'crm:P2_has_type', 'crm:E55_Type1'], ['crm:E22_Man-Made_Object1', 'crm:P24i_changed_ownership_through', 'crm:E8_Acquisition1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span3']]
# Wrong: {('crm:E22_Man-Made_Object1', 'crm:P2_has_type', 'crm:E55_Type1')}
# Precision: 0.9285714285714286
# Recall: 0.8666666666666667
# prune: crm:E74_Group1
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E12_Production1', 'crm:P32_used_general_technique', 'crm:E55_Type1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P65_shows_visual_item', 'crm:E34_Inscription1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'], ['crm:E22_Man-Made_Object1', 'crm:P2_has_type', 'crm:E55_Type2'], ['crm:E22_Man-Made_Object1', 'crm:P24i_changed_ownership_through', 'crm:E8_Acquisition1'], ['crm:E38_Image1', 'crm:P138_represents', 'crm:E22_Man-Made_Object1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span3']]
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E22_Man-Made_Object1', 'crm:P138_represents', 'crm:E38_Image1'], ['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'], ['crm:E22_Man-Made_Object1', 'crm:P2_has_type', 'crm:E55_Type1'], ['crm:E22_Man-Made_Object1', 'crm:P2_has_type', 'crm:E55_Type2'], ['crm:E22_Man-Made_Object1', 'crm:P24i_changed_ownership_through', 'crm:E8_Acquisition1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span3']]
# Wrong: {('crm:E22_Man-Made_Object1', 'crm:P138_represents', 'crm:E38_Image1'), ('crm:E22_Man-Made_Object1', 'crm:P2_has_type', 'crm:E55_Type1')}
# Precision: 0.8571428571428571
# Recall: 0.8
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E21_Person1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'], ['crm:E22_Man-Made_Object1', 'crm:P45_consists_of', 'crm:E57_Material1'], ['crm:E22_Man-Made_Object1', 'crm:P24i_changed_ownership_through', 'crm:E8_Acquisition1'], ['crm:E33_Linguistic_Object1', 'crm:P129_is_about', 'crm:E22_Man-Made_Object1'], ['crm:E38_Image1', 'crm:P138_represents', 'crm:E22_Man-Made_Object1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span3']]
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E21_Person1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'], ['crm:E38_Image1', 'crm:P138_represents', 'crm:E22_Man-Made_Object1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span3']]
# Wrong: set()
# Precision: 1.0
# Recall: 0.8
# prune: crm:E55_Type2
# prune: crm:E74_Group1
# prune: crm:E44_Place_Appellation1
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E21_Person1', 'crm:P74_has_current_or_former_residence', 'crm:E53_Place1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E38_Image1', 'crm:P138_represents', 'crm:E22_Man-Made_Object1'], ['crm:E53_Place1', 'crm:P87_is_identified_by', 'crm:E48_Place_Name1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span3']]
# [['crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E22_Man-Made_Object1', 'crm:P138_represents', 'crm:E38_Image1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span3'], ['crm:E82_Actor_Appellation1', 'crm:P131_is_identified_by', 'crm:E21_Person1']]
# Wrong: {('crm:E22_Man-Made_Object1', 'crm:P138_represents', 'crm:E38_Image1'), ('crm:E82_Actor_Appellation1', 'crm:P131_is_identified_by', 'crm:E21_Person1')}
# Precision: 0.7777777777777778
# Recall: 0.5833333333333334
# [['crm:E33_Linguistic_Object1', 'crm:P129_is_about', 'crm:E39_Actor1'], ['crm:E33_Linguistic_Object2', 'crm:P129_is_about', 'crm:E39_Actor1'], ['crm:E39_Actor1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'], ['crm:E39_Actor1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1']]
# [['crm:E39_Actor1', 'crm:P2_has_type', 'crm:E55_Type1'], ['crm:E39_Actor1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E39_Actor1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'], ['crm:E39_Actor1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1']]
# Wrong: {('crm:E39_Actor1', 'crm:P98i_was_born', 'crm:E67_Birth1'), ('crm:E39_Actor1', 'crm:P2_has_type', 'crm:E55_Type1')}
# Precision: 0.5
# Recall: 0.5
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E12_Production1', 'crm:P32_used_general_technique', 'crm:E55_Type1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'], ['crm:E22_Man-Made_Object1', 'crm:P2_has_type', 'crm:E55_Type2'], ['crm:E22_Man-Made_Object1', 'crm:P2_has_type', 'crm:E55_Type3']]
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E12_Production1', 'crm:P32_used_general_technique', 'crm:E55_Type1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'crm:E22_Man-Made_Object1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'], ['crm:E22_Man-Made_Object1', 'crm:P2_has_type', 'crm:E55_Type2']]
# Wrong: {('crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'crm:E22_Man-Made_Object1')}
# Precision: 0.8888888888888888
# Recall: 0.8888888888888888
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E12_Production1', 'crm:P32_used_general_technique', 'crm:E55_Type1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E21_Person1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'], ['crm:E22_Man-Made_Object1', 'crm:P2_has_type', 'crm:E55_Type2'], ['crm:E22_Man-Made_Object1', 'crm:P24i_changed_ownership_through', 'crm:E8_Acquisition1'], ['crm:E38_Image1', 'crm:P138_represents', 'crm:E22_Man-Made_Object1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span3']]
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Spa1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E21_Person1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'], ['crm:E22_Man-Made_Object1', 'crm:P2_has_type', 'crm:E55_Typ1'], ['crm:E22_Man-Made_Object1', 'crm:P24i_changed_ownership_through', 'crm:E8_Acquisition1'], ['crm:E38_Image1', 'crm:P138_represents', 'crm:E22_Man-Made_Object1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Spa1'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Spa1']]
# Wrong: {('crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Spa1'), ('crm:E22_Man-Made_Object1', 'crm:P2_has_type', 'crm:E55_Typ1'), ('crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Spa1'), ('crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Spa1')}
# Precision: 0.7142857142857143
# Recall: 0.6666666666666666
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E21_Person1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'], ['crm:E22_Man-Made_Object1', 'crm:P24i_changed_ownership_through', 'crm:E8_Acquisition1'], ['crm:E38_Image1', 'crm:P138_represents', 'crm:E22_Man-Made_Object1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span3']]
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E21_Person1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108_has_produced', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'], ['crm:E22_Man-Made_Object1', 'crm:P12_occurred_in_the_presence_of', 'crm:E74_Group1'], ['crm:E38_Image1', 'crm:P138_represents', 'crm:E22_Man-Made_Object1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span3']]
# Wrong: {('crm:E22_Man-Made_Object1', 'crm:P12_occurred_in_the_presence_of', 'crm:E74_Group1'), ('crm:E22_Man-Made_Object1', 'crm:P108_has_produced', 'crm:E12_Production1')}
# Precision: 0.8461538461538461
# Recall: 0.8461538461538461
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E21_Person1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'], ['crm:E22_Man-Made_Object1', 'crm:P2_has_type', 'crm:E55_Type1'], ['crm:E22_Man-Made_Object1', 'crm:P24i_changed_ownership_through', 'crm:E8_Acquisition1'], ['crm:E38_Image1', 'crm:P138_represents', 'crm:E22_Man-Made_Object1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2']]
# [['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E21_Person1'], ['crm:E21_Person1', 'crm:P98i_was_born', 'crm:E67_Birth1'], ['crm:E21_Person1', 'crm:P100i_died_in', 'crm:E69_Death1'], ['crm:E21_Person1', 'crm:P107i_is_current_or_former_member_of', 'crm:E74_Group1'], ['crm:E21_Person1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'], ['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'], ['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'], ['crm:E22_Man-Made_Object1', 'crm:P138_represents', 'crm:E38_Image1'], ['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'], ['crm:E22_Man-Made_Object1', 'crm:P2_has_type', 'crm:E55_Type1'], ['crm:E22_Man-Made_Object1', 'crm:P24i_changed_ownership_through', 'crm:E8_Acquisition1'], ['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'], ['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2']]
# Wrong: {('crm:E22_Man-Made_Object1', 'crm:P138_represents', 'crm:E38_Image1')}
# Precision: 0.9230769230769231
# Recall: 0.9230769230769231
# Mean Precision: 0.7826506826506826
# Mean Recall: 0.7524607278808959
