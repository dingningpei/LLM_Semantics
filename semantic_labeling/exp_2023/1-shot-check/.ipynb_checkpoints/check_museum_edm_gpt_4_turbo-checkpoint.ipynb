# %%
import re

# Read the file content
with open('/root/autodl-tmp/semantic_labeling/exp_2023/1-shot-results/museum_edm_gpt_4_turbo/13.txt', 'r') as file:
    content = file.read()

# Use regex to find all <Step2> sections
step1_sections = re.findall(r'<Step1>(.*?)</Step1>', content, re.DOTALL)

# Store the extracted sections in a list
step1_list = [section.strip() for section in step1_sections]

# Print the list to verify
print(step1_list)
# Out:
# ["[['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'name'],\n['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'],\n['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'],\n['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate']]", "[['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'],\n['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'name'],\n['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'],\n['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'],\n['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate']]", "[['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'],\n['edm:WebResource1', 'karma:classLink', 'photo'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'dimensions'],\n['skos:Concept1', 'skos:prefLabel', 'technique'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'credittext'],\n['dcterms:PeriodOfTime1', 'dcterms:date', 'artyear'],\n['foaf:Document1', 'karma:classLink', 'link'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:description', 'artdesc'],\n['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'artist'],\n['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'],\n['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'artistBirth'],\n['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'artistDeath']]", "[['aac-ont:CulturalHeritageObject1', 'dcterms:description', 'description'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'],\n['aac-ont:Person1', 'foaf:name', 'artist'],\n['skos:Concept1', 'skos:broadMatch', 'subjectTags'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'credit'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:medium', 'materials'],\n['edm:WebResource1', 'karma:classLink', 'imageURL'],\n['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'accessionID'],\n['dcterms:PhysicalResource1', 'dcterms:created', 'dateCreated'],\n['dcterms:PhysicalResource1', 'dcterms:extent', 'dimensions'],\n['skos:Concept1', 'skos:prefLabel', 'techniqueType']]", "[['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'idNumber'],\n['skos:Concept1', 'skos:prefLabel', 'category'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'],\n['aac-ont:Person1', 'foaf:name', 'maker'],\n['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'makerBioCountry'],\n['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'],\n['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate'],\n['aac-ont:Place1', 'rdfs:label', 'placeMade'],\n['skos:Concept1', 'dcterms:medium', 'materials'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'measurements'],\n['aac-ont:CulturalHeritageObject1', 'dc:description', 'description'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'creditLine'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:rightsHolder', 'owner'],\n['skos:Concept1', 'skos:prefLabel', 'option'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:date', 'createDate']]", "[['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'],\n['foaf:Document1', 'karma:classLink', 'sourceURL'],\n['edm:WebResource1', 'karma:classLink', 'imageURL'],\n['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'artist'],\n['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'],\n['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'],\n['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate'],\n['aac-ont:CulturalHeritageObject1', 'dc:date', 'creationDate'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:medium', 'materials'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'dimensions'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'creditLine'],\n['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'accessionNumber'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:description', 'galleryLabel'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'provenance'],\n['foaf:Document2', 'kar ...

# %%
import json

def load_json(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)
def normalize_semantics(semantics):
    # 提取并返回去掉编号的部分
    return [tuple(item[0].rsplit('-', 1)[0] + '-' + item[0].split('-')[-1] for item in triple) for triple in semantics]
def calculate_precision_recall(gold_semantics, predicted_semantics):
    # 先归一化语义三元组
    gold_set = set(normalize_semantics(gold_semantics))
    predicted_set = set(normalize_semantics(predicted_semantics))

    # 计算真阳性、假阳性和假阴性
    true_positives = len(gold_set.intersection(predicted_set))
    false_positives = len(predicted_set - gold_set)
    false_negatives = len(gold_set - predicted_set)
    print(f"Wrong: {str(predicted_set - gold_set)}")

    # 计算精确度和召回率
    if len(predicted_set) == 1 and len(predicted_set) == 0 and len(gold_set) == 0:
        precision = 1
        recall = 1
    else:
        precision = true_positives / (len(predicted_set)) if (true_positives + false_positives) > 0 else 0
        recall = true_positives / len(gold_set) if (true_positives + false_negatives) > 0 else 0
    return precision, recall

# %%
gold_list = [
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s03-ima-artists-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s18-s-indianapolis-artists-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s17-s-houston-museum-of-fine-arts-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s10-s-18-artworks-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s27-wildlife-art-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s04-ima-artworks-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s24-s-oakland-museum-paintings-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s19-s-indianapolis-artworks-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s20-s-lacma-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s11-s-19-artists-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s28-gilcrease-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s15-s-detroit-institute-of-art-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s23-s-norton-simon-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s13-s-art-institute-of-chicago-model.json"
]
pre = []
rec = []

# %%
for i, j in enumerate(gold_list):  
    gold_semantics = load_json(j)['semantic_triples']
    predicted_semantics = [i.replace('\'', '').split(", ") for i in step1_list[i][2:-2].split("],\n[")]
    print(gold_semantics)
    print(predicted_semantics)
    precision, recall = calculate_precision_recall(gold_semantics, predicted_semantics)
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    pre.append(precision)
    rec.append(recall)
print(f"Mean Precision: {sum(pre) / len(pre)}")
print(f"Mean Recall: {sum(rec) / len(rec)}")
# Out:
# [['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'name'], ['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate']]
# [['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'name'], ['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate']]
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# [['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'name'], ['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate']]
# [['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'name'], ['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate']]
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# [['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['edm:WebResource1', 'karma:classLink', 'photo'], ['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'dimensions'], ['aac-ont:CulturalHeritageObject1', 'dcterms:medium', 'technique'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'credittext'], ['aac-ont:CulturalHeritageObject1', 'dcterms:created', 'artyear'], ['foaf:Document1', 'karma:classLink', 'link'], ['aac-ont:CulturalHeritageObject1', 'dcterms:description', 'artdesc'], ['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'artist'], ['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'artistBirth'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'artistDeath']]
# [['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['edm:WebResource1', 'karma:classLink', 'photo'], ['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'dimensions'], ['skos:Concept1', 'skos:prefLabel', 'technique'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'credittext'], ['dcterms:PeriodOfTime1', 'dcterms:date', 'artyear'], ['foaf:Document1', 'karma:classLink', 'link'], ['aac-ont:CulturalHeritageObject1', 'dcterms:description', 'artdesc'], ['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'artist'], ['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'artistBirth'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'artistDeath']]
# Wrong: {('s-s', 's-s', 't-t'), ('d-d', 'd-d', 'a-a')}
# Precision: 0.8
# Recall: 1.0
# [['aac-ont:CulturalHeritageObject1', 'dcterms:description', 'description'], ['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'artist'], ['skos:Concept1', 'skos:prefLabel', 'subjectTags'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'credit'], ['aac-ont:CulturalHeritageObject1', 'dcterms:medium', 'materials'], ['edm:WebResource1', 'karma:classLink', 'imageURL'], ['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'accessionID'], ['aac-ont:CulturalHeritageObject1', 'dcterms:created', 'dateCreated'], ['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'dimensions'], ['skos:Concept2', 'skos:prefLabel', 'techniqueType']]
# [['aac-ont:CulturalHeritageObject1', 'dcterms:description', 'description'], ['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['aac-ont:Person1', 'foaf:name', 'artist'], ['skos:Concept1', 'skos:broadMatch', 'subjectTags'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'credit'], ['aac-ont:CulturalHeritageObject1', 'dcterms:medium', 'materials'], ['edm:WebResource1', 'karma:classLink', 'imageURL'], ['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'accessionID'], ['dcterms:PhysicalResource1', 'dcterms:created', 'dateCreated'], ['dcterms:PhysicalResource1', 'dcterms:extent', 'dimensions'], ['skos:Concept1', 'skos:prefLabel', 'techniqueType']]
# Wrong: {('d-d', 'd-d', 'd-d'), ('a-a', 'f-f', 'a-a')}
# Precision: 0.8
# Recall: 0.8888888888888888
# [['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'idNumber'], ['skos:Concept2', 'skos:prefLabel', 'category'], ['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'maker'], ['aac-ont:Person1', 'ElementsGr2:biographicalInformation', 'makerBioCountry'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate'], ['aac-ont:Place1', 'rdfs:label', 'placeMade'], ['aac-ont:CulturalHeritageObject1', 'dcterms:medium', 'materials'], ['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'measurements'], ['aac-ont:CulturalHeritageObject1', 'dcterms:description', 'description'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'creditLine'], ['aac-ont:CulturalHeritageObject1', 'dcterms:rightsHolder', 'owner'], ['skos:Concept1', 'skos:prefLabel', 'option'], ['aac-ont:CulturalHeritageObject1', 'dcterms:created', 'createDate']]
# [['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'idNumber'], ['skos:Concept1', 'skos:prefLabel', 'category'], ['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['aac-ont:Person1', 'foaf:name', 'maker'], ['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'makerBioCountry'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate'], ['aac-ont:Place1', 'rdfs:label', 'placeMade'], ['skos:Concept1', 'dcterms:medium', 'materials'], ['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'measurements'], ['aac-ont:CulturalHeritageObject1', 'dc:description', 'description'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'creditLine'], ['aac-ont:CulturalHeritageObject1', 'dcterms:rightsHolder', 'owner'], ['skos:Concept1', 'skos:prefLabel', 'option'], ['aac-ont:CulturalHeritageObject1', 'dcterms:date', 'createDate']]
# Wrong: {('a-a', 'f-f', 'm-m'), ('s-s', 'd-d', 'm-m')}
# Precision: 0.8571428571428571
# Recall: 1.0
# [['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['foaf:Document1', 'karma:classLink', 'sourceURL'], ['edm:WebResource1', 'karma:classLink', 'imageURL'], ['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'artist'], ['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate'], ['aac-ont:CulturalHeritageObject1', 'dcterms:created', 'creationDate'], ['aac-ont:CulturalHeritageObject1', 'dcterms:medium', 'materials'], ['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'dimensions'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'creditLine'], ['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'accessionNumber'], ['aac-ont:CulturalHeritageObject1', 'dcterms:description', 'galleryLabel'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'provenance'], ['foaf:Document2', 'karma:classLink', 'relatedArtworksURL'], ['aac-ont:CulturalHeritageObject2', 'dcterms:title', 'relatedArtworksTitle'], ['skos:Concept1', 'skos:prefLabel', 'keywords']]
# [['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['foaf:Document1', 'karma:classLink', 'sourceURL'], ['edm:WebResource1', 'karma:classLink', 'imageURL'], ['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'artist'], ['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate'], ['aac-ont:CulturalHeritageObject1', 'dc:date', 'creationDate'], ['aac-ont:CulturalHeritageObject1', 'dcterms:medium', 'materials'], ['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'dimensions'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'creditLine'], ['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'accessionNumber'], ['aac-ont:CulturalHeritageObject1', 'dcterms:description', 'galleryLabel'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'provenance'], ['foaf:Document2', 'karma:classLink', 'relatedArtworksURL'], ['aac-ont:CulturalHeritageObject2', 'dcterms:title', 'relatedArtworksTitle'], ['skos:Concept1', 'skos:prefLabel', 'keywords']]
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# [['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'artistName'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate'], ['aac-ont:CulturalHeritageObject1', 'dcterms:medium', 'subtypeOfArt'], ['skos:Concept2', 'skos:prefLabel', 'typeOfArt'], ['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['aac-ont:CulturalHeritageObject1', 'dcterms:created', 'dateMade'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'credit'], ['skos:Concept1', 'skos:prefLabel', 'keywords'], ['aac-ont:CulturalHeritageObject1', 'dcterms:description', 'inscription'], ['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'accessionID'], ['edm:WebResource1', 'karma:classLink', 'picURL'], ['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'dimensions']]
# [['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'artistName'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate'], ['skos:Concept1', 'skos:prefLabel', 'subtypeOfArt'], ['skos:Concept1', 'skos:prefLabel', 'typeOfArt'], ['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['aac-ont:CulturalHeritageObject1', 'dcterms:date', 'dateMade'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'credit'], ['aac-ont:CulturalHeritageObject1', 'dc:subject', 'keywords'], ['aac-ont:CulturalHeritageObject1', 'dcterms:description', 'inscription'], ['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'accessionID'], ['edm:WebResource1', 'karma:classLink', 'picURL'], ['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'dimensions']]
# Wrong: {('a-a', 'd-d', 'k-k'), ('s-s', 's-s', 's-s')}
# Precision: 0.8333333333333334
# Recall: 0.8333333333333334
# [['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['foaf:Document1', 'karma:classLink', 'sourceURL'], ['edm:WebResource1', 'karma:classLink', 'imageURL'], ['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'artist'], ['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate'], ['aac-ont:CulturalHeritageObject1', 'dcterms:created', 'creationDate'], ['aac-ont:CulturalHeritageObject1', 'dcterms:medium', 'materials'], ['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'dimensions'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'creditLine'], ['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'accessionNumber'], ['aac-ont:CulturalHeritageObject1', 'dcterms:description', 'galleryLabel'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'provenance'], ['foaf:Document2', 'karma:classLink', 'relatedArtworksURL'], ['aac-ont:CulturalHeritageObject2', 'dcterms:title', 'relatedArtworksTitle'], ['skos:Concept1', 'skos:prefLabel', 'keywords']]
# [['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['foaf:Document1', 'karma:classLink', 'sourceURL'], ['edm:WebResource1', 'karma:classLink', 'imageURL'], ['aac-ont:Person1', 'foaf:name', 'artist'], ['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'], ['aac-ont:Person1', 'dcterms:dateOfBirth', 'birthDate'], ['aac-ont:Person1', 'dcterms:dateOfDeath', 'deathDate'], ['aac-ont:CulturalHeritageObject1', 'dcterms:date', 'creationDate'], ['aac-ont:CulturalHeritageObject1', 'dcterms:medium', 'materials'], ['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'dimensions'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'creditLine'], ['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'accessionNumber'], ['aac-ont:CulturalHeritageObject1', 'dc:description', 'galleryLabel'], ['foaf:Document1', 'karma:classLink', 'relatedArtworksURL'], ['skos:Concept1', 'skos:prefLabel', 'relatedArtworksTitle'], ['skos:Concept1', 'skos:prefLabel', 'keywords']]
# Wrong: {('a-a', 'd-d', 'b-b'), ('s-s', 's-s', 'r-r'), ('a-a', 'f-f', 'a-a')}
# Precision: 0.7857142857142857
# Recall: 0.6875
# [['aac-ont:CulturalHeritageObject1', 'aac-ont:objectId', 'ID'], ['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'artistName'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate'], ['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['aac-ont:CulturalHeritageObject1', 'dcterms:created', 'artworkDate'], ['aac-ont:CulturalHeritageObject1', 'dcterms:description', 'artworkDetails'], ['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'origin'], ['edm:WebResource1', 'karma:classLink', 'imageURL']]
# [['aac-ont:CulturalHeritageObject1', 'aac-ont:objectId', 'ID'], ['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'artistName'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate'], ['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['aac-ont:CulturalHeritageObject1', 'dcterms:date', 'artworkDate'], ['aac-ont:CulturalHeritageObject1', 'dcterms:description', 'artworkDetails'], ['aac-ont:CulturalHeritageObject1', 'dcterms:identifier', 'origin'], ['edm:WebResource1', 'karma:classLink', 'imageURL']]
# Wrong: {('a-a', 'd-d', 'o-o')}
# Precision: 0.875
# Recall: 0.875
# [['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'artistName'], ['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate'], ['aac-ont:Person1', 'ElementsGr2:biographicalInformation', 'longBiography'], ['aac-ont:Person1', 'ElementsGr2:professionOrOccupation', 'occupation']]
# [['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'artistName'], ['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate'], ['aac-ont:Person1', 'ElementsGr2:biographicalInformation', 'longBiography'], ['skos:Concept1', 'skos:prefLabel', 'occupation']]
# Wrong: {('s-s', 's-s', 'o-o')}
# Precision: 0.8333333333333334
# Recall: 0.8333333333333334
# [['aac-ont:CulturalHeritageObject1', 'aac-ont:objectId', 'objectID'], ['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'objectNumber'], ['skos:Concept1', 'skos:prefLabel', 'classification'], ['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'alphaSort'], ['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['aac-ont:CulturalHeritageObject1', 'dcterms:created', 'dated'], ['aac-ont:CulturalHeritageObject1', 'dcterms:medium', 'medium'], ['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'dimensions'], ['aac-ont:CulturalHeritageObject1', 'dcterms:description', 'description']]
# [['aac-ont:CulturalHeritageObject1', 'aac-ont:objectId', 'objectID'], ['aac-ont:CulturalHeritageObject1', 'dc:identifier', 'objectNumber'], ['aac-ont:CulturalHeritageObject1', 'dc:type', 'classification'], ['aac-ont:Person1', 'foaf:name', 'alphaSort'], ['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['aac-ont:CulturalHeritageObject1', 'dcterms:date', 'dated'], ['aac-ont:CulturalHeritageObject1', 'dcterms:medium', 'medium'], ['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'dimensions'], ['aac-ont:CulturalHeritageObject1', 'dc:description', 'description']]
# Wrong: {('a-a', 'd-d', 'c-c'), ('a-a', 'd-d', 'o-o'), ('a-a', 'f-f', 'a-a')}
# Precision: 0.5714285714285714
# Recall: 0.6666666666666666
# [['edm:WebResource1', 'karma:classLink', 'imageURL'], ['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'name'], ['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birth'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'death'], ['aac-ont:CulturalHeritageObject1', 'dcterms:created', 'date'], ['aac-ont:CulturalHeritageObject1', 'dcterms:medium', 'medium'], ['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'dimensions'], ['skos:Concept1', 'skos:prefLabel', 'classification'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'credit'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'provenance'], ['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'accession']]
# [['edm:WebResource1', 'karma:classLink', 'imageURL'], ['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['aac-ont:Person1', 'foaf:name', 'name'], ['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birth'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'death'], ['aac-ont:CulturalHeritageObject1', 'dcterms:date', 'date'], ['aac-ont:CulturalHeritageObject1', 'dcterms:medium', 'medium'], ['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'dimensions'], ['aac-ont:CulturalHeritageObject1', 'skos:prefLabel', 'classification'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'credit'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'provenance'], ['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'accession']]
# Wrong: {('a-a', 'f-f', 'n-n'), ('a-a', 's-s', 'c-c')}
# Precision: 0.8333333333333334
# Recall: 0.9090909090909091
# [['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'access'], ['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'artist'], ['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate'], ['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['aac-ont:CulturalHeritageObject1', 'dcterms:created', 'made'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'prov'], ['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'dim'], ['edm:WebResource1', 'karma:classLink', 'imageURL']]
# [['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'access'], ['aac-ont:Person1', 'foaf:name', 'artist'], ['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate'], ['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'], ['aac-ont:CulturalHeritageObject1', 'ElementsGr2:dateAssociatedWithThePerson', 'made'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'prov'], ['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'dim'], ['edm:WebResource1', 'karma:classLink', 'imageURL']]
# Wrong: {('a-a', 'E-E', 'm-m'), ('a-a', 'f-f', 'a-a')}
# Precision: 0.8
# Recall: 0.8
# [['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'artistName'], ['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthYear'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathYear'], ['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'titleofartwork'], ['aac-ont:CulturalHeritageObject1', 'dcterms:medium', 'typeofartwork'], ['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'dimensions'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'credit'], ['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'accessionID'], ['edm:WebResource1', 'karma:classLink', 'imageURL']]
# [['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'artistName'], ['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'], ['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthYear'], ['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathYear'], ['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'titleofartwork'], ['skos:Concept1', 'skos:prefLabel', 'typeofartwork'], ['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'dimensions'], ['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'credit'], ['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'accessionID'], ['edm:WebResource1', 'karma:classLink', 'imageURL']]
# Wrong: {('s-s', 's-s', 't-t')}
# Precision: 0.9
# Recall: 1.0
# Mean Precision: 0.849234693877551
# Mean Recall: 0.8924152236652236

# %%
import re

# Read the file content
with open('/root/autodl-tmp/semantic_labeling/exp_2023/1-shot-results/museum_edm_gpt_4_turbo/13.txt', 'r') as file:
    content = file.read()

# Use regex to find all <Step2> sections
step2_sections = re.findall(r'<Step2>(.*?)</Step2>', content, re.DOTALL)

# Store the extracted sections in a list
step2_list = [section.strip() for section in step2_sections]

# Print the list to verify
print(step2_list)
# Out:
# ['[]', "[['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'],\n['aac-ont:CulturalHeritageObject2', 'dcterms:creator', 'aac-ont:Person2'],\n['aac-ont:CulturalHeritageObject3', 'dcterms:creator', 'aac-ont:Person3']]", "[['aac-ont:CulturalHeritageObject1', 'edm:isShownBy', 'edm:WebResource1'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:created', 'dcterms:PeriodOfTime1'],\n['aac-ont:CulturalHeritageObject2', 'dcterms:creator', 'aac-ont:Person2'],\n['aac-ont:CulturalHeritageObject2', 'foaf:page', 'foaf:Document2'],\n['aac-ont:Person2', 'ElementsGr2:dateOfBirth', 'dcterms:PeriodOfTime2'],\n['aac-ont:Person2', 'ElementsGr2:dateOfDeath', 'dcterms:PeriodOfTime3']]", "[['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'],\n['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'],\n['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1'],\n['dcterms:PhysicalResource1', 'dcterms:isPartOf', 'aac-ont:CulturalHeritageObject1'],\n['dcterms:PhysicalResource1', 'dcterms:format', 'skos:Concept1']]", "[['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'],\n['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1'],\n['aac-ont:Person1', 'ElementsGr2:placeOfBirth', 'aac-ont:Place1'],\n['foaf:Document1', 'edm:isShownBy', 'edm:WebResource1'],\n['foaf:Document1', 'foaf:page', 'aac-ont:CulturalHeritageObject1'],\n['edm:WebResource1', 'foaf:depicts', 'aac-ont:CulturalHeritageObject1'],\n['edm:WebResource1', 'edm:hasView', 'aac-ont:CulturalHeritageObject1']]", "[['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'],\n['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'],\n['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1'],\n['aac-ont:CulturalHeritageObject1', 'foaf:page', 'foaf:Document1'],\n['foaf:Document1', 'foaf:isPrimaryTopicOf', 'foaf:Document2'],\n['foaf:Document2', 'edm:isAnnotationOf', 'aac-ont:CulturalHeritageObject2']]", "[['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'],\n['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'],\n['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1']]", "[['edm:EuropeanaObject1', 'edm:isShownAt', 'foaf:Document1'],\n['edm:EuropeanaObject1', 'edm:isShownBy', 'edm:WebResource1'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'],\n['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1'],\n['aac-ont:CulturalHeritageObject1', 'foaf:page', 'foaf:Document1'],\n['foaf:OnlineAccount1', 'foaf:page', 'foaf:Document1'],\n['skos:Concept1', 'skos:related', 'skos:Concept1'],\n['foaf:Document1', 'foaf:primaryTopic', 'aac-ont:CulturalHeritageObject1']]", "[['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'],\n['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1']]", "[[ 'aac-ont:Person1', 'aac-ont:objectId', 'skos:Concept1']]", "[['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1']]", "[['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'],\n['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'],\n['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1'],\n['aac-ont:CulturalHeritageObject1', 'foaf:page', 'foaf:Document1']]", "[['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1 ...

# %%
import json
def load_json(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)
        
def calculate_precision_recall(gold_semantics, predicted_semantics):
    gold_set = set(tuple(item) for item in gold_semantics)
    predicted_set = set(tuple(item) for item in predicted_semantics)
 
    # Calculate true positives, false positives, and false negatives
    true_positives = len(gold_set.intersection(predicted_set))
    false_positives = len(predicted_set - gold_set)
    false_negatives = len(gold_set - predicted_set)
    print(f"Wrong: {str(predicted_set - gold_set)}")

    # Calculate precision and recall
    #if len(predicted_set) == 1 and len(predicted_set[0]) == 0 and len(gold_set) == 0:
    if len(predicted_set) == 0 and len(gold_set) == 0:
        precision = 1
        recall = 1
    else:
        precision = true_positives / (len(predicted_set)) if (true_positives + false_positives) > 0 else 0
        recall = true_positives / len(gold_set) if (true_positives + false_negatives) > 0 else 0
    return precision, recall

# %%
import networkx as nx

def prune_wrong(semantics, sm_type):
    G = nx.DiGraph()
    for item in semantics:
        try:
            s, p, o = item  # 尝试解包
            G.add_edge(s, o, predicate=p)
        except ValueError:
            print(f"Skipping invalid semantic: {item}")  # 打印跳过的项

    # Function to find leaf nodes in the graph
    Stop_flag = True
    while Stop_flag:
        Stop_flag = False
        nodes_to_check = list(G.nodes())  # Create a copy of the nodes
        for i in nodes_to_check:
            if G.out_degree(i) == 0 and G.in_degree(i) >= 1:
                if i not in sm_type:
                    print(f"prune: {i}")
                    G.remove_node(i)
                    Stop_flag = True

    updated_triples = [[s, G.edges[s, o]['predicate'], o] for s, o in G.edges()]
    return updated_triples

# %%
gold_list = [
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s03-ima-artists-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s18-s-indianapolis-artists-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s17-s-houston-museum-of-fine-arts-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s10-s-18-artworks-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s27-wildlife-art-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s04-ima-artworks-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s24-s-oakland-museum-paintings-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s19-s-indianapolis-artworks-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s20-s-lacma-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s11-s-19-artists-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s28-gilcrease-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s15-s-detroit-institute-of-art-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s23-s-norton-simon-model.json",
    "/root/autodl-tmp/semantic_labeling/data/museum-edm/models_triples_json/s13-s-art-institute-of-chicago-model.json"
]

# %%
def convert_notation(semantics):
    if len(semantics) == 0:
        return semantics
    map_dict = {}
    for i, item in enumerate(semantics):
        if map_dict.get(item[0][:-1]) is None:
            map_dict[item[0][:-1]] = [item[0]]
        else:
            if item[0] not in map_dict[item[0][:-1]]:
                map_dict[item[0][:-1]].append(item[0])
        if map_dict.get(item[2][:-1]) is None:
            map_dict[item[2][:-1]] = [item[2]]
        else:
            if item[2] not in map_dict[item[2][:-1]]:
                map_dict[item[2][:-1]].append(item[2])
    convert_dict = {}
    for key, value in map_dict.items():
        for i, item in enumerate(value):
            if item[-1] != str(i+1):
                convert_dict[item] = item[:-1] + str(i+1)
    for i, item in enumerate(semantics):
        if convert_dict.get(item[0]) is not None:
            semantics[i][0] = convert_dict[item[0]]
        if convert_dict.get(item[2]) is not None:
            semantics[i][2] = convert_dict[item[2]]
    # print(map_dict)
    # print(convert_dict)
    return semantics

# %%
pre = []
rec = []
for i, j in enumerate(gold_list):  
    gold_semantics = load_json(j)['internal_link_triples']
    predicted_semantics = [i.replace("'", "").split(", ") for i in step2_list[i][2:-2].split("],\n[")]
    #Addded
    semantic_type = [i.replace("'", "").split(", ") for i in step1_list[i][2:-2].split("],\n[")]
    semantic_type = [i[0] for i in semantic_type]
    predicted_semantics = prune_wrong(predicted_semantics, semantic_type)
    gold_semantics = sorted(gold_semantics, key=lambda x: (x[0], x[2], x[1]))
    predicted_semantics = sorted(predicted_semantics, key=lambda x: (x[0], x[2], x[1]))
    gold_semantics = convert_notation(gold_semantics)
    predicted_semantics = convert_notation(predicted_semantics)
    print(gold_semantics)
    print(predicted_semantics)
    #Added
    precision, recall = calculate_precision_recall(gold_semantics, predicted_semantics)
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    pre.append(precision)
    rec.append(recall)
print(f"Mean Precision: {sum(pre) / len(pre)}")
print(f"Mean Recall: {sum(rec) / len(rec)}")
# Out:
# Skipping invalid semantic: ['']
# []
# []
# Wrong: set()
# Precision: 1
# Recall: 1
# prune: aac-ont:Person2
# prune: aac-ont:Person3
# [['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1']]
# [['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1']]
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# prune: foaf:Document2
# prune: dcterms:PeriodOfTime2
# prune: dcterms:PeriodOfTime3
# prune: aac-ont:Person2
# [['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'], ['aac-ont:CulturalHeritageObject1', 'foaf:page', 'foaf:Document1'], ['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'], ['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1']]
# [['aac-ont:CulturalHeritageObject1', 'dcterms:created', 'dcterms:PeriodOfTime1'], ['aac-ont:CulturalHeritageObject1', 'edm:isShownBy', 'edm:WebResource1']]
# Wrong: {('aac-ont:CulturalHeritageObject1', 'dcterms:created', 'dcterms:PeriodOfTime1'), ('aac-ont:CulturalHeritageObject1', 'edm:isShownBy', 'edm:WebResource1')}
# Precision: 0.0
# Recall: 0.0
# [['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'], ['aac-ont:CulturalHeritageObject1', 'dcterms:subject', 'skos:Concept1'], ['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept2'], ['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'], ['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1']]
# [['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'], ['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1'], ['dcterms:PhysicalResource1', 'dcterms:isPartOf', 'aac-ont:CulturalHeritageObject1'], ['dcterms:PhysicalResource1', 'dcterms:format', 'skos:Concept1'], ['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'], ['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1']]
# Wrong: {('aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1'), ('dcterms:PhysicalResource1', 'dcterms:isPartOf', 'aac-ont:CulturalHeritageObject1'), ('dcterms:PhysicalResource1', 'dcterms:format', 'skos:Concept1')}
# Precision: 0.5
# Recall: 0.6
# [['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'], ['aac-ont:CulturalHeritageObject1', 'aac-ont:associatedPlace', 'aac-ont:Place1'], ['aac-ont:CulturalHeritageObject1', 'dcterms:subject', 'skos:Concept1'], ['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept2']]
# [['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'], ['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1'], ['aac-ont:Person1', 'ElementsGr2:placeOfBirth', 'aac-ont:Place1'], ['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'], ['edm:WebResource1', 'edm:hasView', 'aac-ont:CulturalHeritageObject1'], ['foaf:Document1', 'foaf:page', 'aac-ont:CulturalHeritageObject1'], ['foaf:Document1', 'edm:isShownBy', 'edm:WebResource1']]
# Wrong: {('edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'), ('edm:WebResource1', 'edm:hasView', 'aac-ont:CulturalHeritageObject1'), ('foaf:Document1', 'foaf:page', 'aac-ont:CulturalHeritageObject1'), ('aac-ont:Person1', 'ElementsGr2:placeOfBirth', 'aac-ont:Place1'), ('foaf:Document1', 'edm:isShownBy', 'edm:WebResource1'), ('aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1')}
# Precision: 0.14285714285714285
# Recall: 0.25
# [['aac-ont:CulturalHeritageObject1', 'edm:isRelatedTo', 'aac-ont:CulturalHeritageObject2'], ['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'], ['aac-ont:CulturalHeritageObject1', 'foaf:page', 'foaf:Document1'], ['aac-ont:CulturalHeritageObject1', 'dcterms:subject', 'skos:Concept1'], ['aac-ont:CulturalHeritageObject2', 'foaf:page', 'foaf:Document2'], ['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'], ['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1']]
# [['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'], ['aac-ont:CulturalHeritageObject1', 'foaf:page', 'foaf:Document1'], ['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1'], ['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'], ['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1'], ['foaf:Document1', 'foaf:isPrimaryTopicOf', 'foaf:Document2'], ['foaf:Document2', 'edm:isAnnotationOf', 'aac-ont:CulturalHeritageObject2']]
# Wrong: {('foaf:Document1', 'foaf:isPrimaryTopicOf', 'foaf:Document2'), ('foaf:Document2', 'edm:isAnnotationOf', 'aac-ont:CulturalHeritageObject2'), ('aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1')}
# Precision: 0.5714285714285714
# Recall: 0.5714285714285714
# [['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'], ['aac-ont:CulturalHeritageObject1', 'dcterms:subject', 'skos:Concept1'], ['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept2'], ['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'], ['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1']]
# [['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'], ['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1'], ['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'], ['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1']]
# Wrong: {('aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1')}
# Precision: 0.75
# Recall: 0.6
# [['aac-ont:CulturalHeritageObject1', 'edm:isRelatedTo', 'aac-ont:CulturalHeritageObject2'], ['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'], ['aac-ont:CulturalHeritageObject1', 'foaf:page', 'foaf:Document1'], ['aac-ont:CulturalHeritageObject1', 'dcterms:subject', 'skos:Concept1'], ['aac-ont:CulturalHeritageObject2', 'foaf:page', 'foaf:Document2'], ['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'], ['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1']]
# [['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'], ['aac-ont:CulturalHeritageObject1', 'foaf:page', 'foaf:Document1'], ['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1'], ['edm:EuropeanaObject1', 'edm:isShownBy', 'edm:WebResource1'], ['edm:EuropeanaObject1', 'edm:isShownAt', 'foaf:Document1'], ['foaf:Document1', 'foaf:primaryTopic', 'aac-ont:CulturalHeritageObject1'], ['foaf:OnlineAccount1', 'foaf:page', 'foaf:Document1'], ['skos:Concept1', 'skos:related', 'skos:Concept1']]
# Wrong: {('edm:EuropeanaObject1', 'edm:isShownAt', 'foaf:Document1'), ('foaf:Document1', 'foaf:primaryTopic', 'aac-ont:CulturalHeritageObject1'), ('edm:EuropeanaObject1', 'edm:isShownBy', 'edm:WebResource1'), ('foaf:OnlineAccount1', 'foaf:page', 'foaf:Document1'), ('aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1'), ('skos:Concept1', 'skos:related', 'skos:Concept1')}
# Precision: 0.25
# Recall: 0.2857142857142857
# [['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'], ['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'], ['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1']]
# [['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'], ['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'], ['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1']]
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# []
# [[' aac-ont:Person1', 'aac-ont:objectId', 'skos:Concept1']]
# Wrong: {(' aac-ont:Person1', 'aac-ont:objectId', 'skos:Concept1')}
# Precision: 0.0
# Recall: 0
# [['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'], ['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1']]
# [['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'], ['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1']]
# Wrong: {('edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1')}
# Precision: 0.5
# Recall: 0.5
# prune: skos:Concept1
# prune: foaf:Document1
# [['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'], ['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1'], ['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'], ['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1']]
# [['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'], ['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'], ['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1']]
# Wrong: set()
# Precision: 1.0
# Recall: 0.75
# [['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'], ['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'], ['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1']]
# [['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'], ['aac-ont:CulturalHeritageObject1', 'foaf:page', 'edm:WebResource1'], ['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1']]
# Wrong: {('aac-ont:CulturalHeritageObject1', 'foaf:page', 'edm:WebResource1')}
# Precision: 0.6666666666666666
# Recall: 0.6666666666666666
# [['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'], ['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'], ['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1']]
# [['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'], ['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1'], ['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'], ['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1']]
# Wrong: {('aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1')}
# Precision: 0.75
# Recall: 1.0
# Mean Precision: 0.5807823129251701
# Mean Recall: 0.5874149659863946
