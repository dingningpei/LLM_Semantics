# %%
import re

# Read the file content
with open('/root/autodl-tmp/semantic_labeling/exp_2023/1-shot-results/soccer_gpt_4_turbo/5.txt', 'r') as file:
    content = file.read()

# Use regex to find all <Step2> sections
step1_sections = re.findall(r'<Step1>(.*?)</Step1>', content, re.DOTALL)

# Store the extracted sections in a list
step1_list = [section.strip() for section in step1_sections]

# Print the list to verify
print(step1_list)
# Out:
# ["[['schema:Player1', 'schema:age', 'Age'],\n['schema:Player1', 'schema:tag', 'Number'],\n['schema:Player1', 'schema:playPosition', 'Position'],\n['schema:Player1', 'schema:name', 'Player'],\n['schema:Place1', 'schema:name', 'Country']]", "[['schema:Player1', 'schema:alternateName', 'Shirt Name'],\n['schema:Player1', 'schema:birthDate', 'Date of Birth'],\n['schema:Player1', 'schema:familyName', 'Last Name'],\n['schema:Player1', 'schema:givenName', 'First Name'],\n['schema:Player1', 'schema:name', 'FIFA Display Name'],\n['schema:Player1', 'schema:birthPlace', 'Country'],\n['schema:Player1', 'schema:height', 'Height'],\n['schema:Player1', 'schema:tag', 'No.'],\n['schema:Player1', 'schema:playPosition', 'Position'],\n['schema:SportsClub1', 'schema:name', 'Club'],\n['schema:SportsClub1', 'schema:birthPlace', 'Club (Country)']]", "[['schema:Person1', 'schema:displayName', 'displayName'],\n['schema:Person1', 'schema:givenName', 'firstName'],\n['schema:Person1', 'schema:familyName', 'lastName'],\n['schema:Person1', 'schema:name', 'fullName'],\n['schema:Person1', 'schema:alternateName', 'shortName'],\n['schema:League1', 'schema:name', 'leagueName'],\n['schema:League1', 'schema:alternateName', 'leagueShortname']]", "[['schema:Player1', 'schema:tag', 'Number'],\n['schema:Player1', 'schema:name', 'FullName'],\n['schema:Player1', 'schema:playPosition', 'Position'],\n['schema:Player1', 'schema:birthDate', 'DateOfBirth'],\n['schema:SportsClub1', 'schema:name', 'Club'],\n['schema:SportsClub1', 'schema:alternateName', 'ClubCountry'],\n['schema:Player1', 'schema:isCaptain', 'IsCaptain']]", "[['schema:Player1', 'schema:playPosition', 'Position'],\n['schema:Player1', 'schema:name', 'Player'],\n['schema:Player1', 'schema:birthPlace', 'Country'],\n['schema:Player1', 'schema:height', 'Height'],\n['schema:Player1', 'schema:age', 'Age'],\n['schema:Player1', 'schema:birthDate', 'D.O.B'],\n['schema:Player1', 'schema:numberOfPlayedGames', 'Caps'],\n['schema:Player1', 'schema:goalScored', 'International goals'],\n['schema:SportsClub1', 'schema:name', 'Club'],\n['schema:Player1', 'schema:tag', 'Number']]", "[['schema:Player1', 'schema:givenName', 'fn'],\n['schema:Player1', 'schema:familyName', 'ln'],\n['schema:Player1', 'schema:nationality', 'cn'],\n['schema:Player1', 'schema:age', 'ag'],\n['schema:Player1', 'schema:alternateName', 'sn'],\n['schema:Player1', 'schema:height', 'ht'],\n['schema:SportsClub1', 'schema:name', 'cb'],\n['schema:Player1', 'schema:playPosition', 'ps'],\n['schema:Player1', 'schema:number', 'no'],\n['schema:Player1', 'schema:birthDate', 'db'],\n['schema:Player1', 'schema:goalScored', 'go/at'],\n['schema:SportsTeam1', 'schema:alternateName', 'nt']]"]

# %%
import json

def load_json(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)
def calculate_precision_recall(gold_semantics, predicted_semantics):
    
    gold_set = set(tuple(item) for item in gold_semantics)
    predicted_set = set(tuple(item) for item in predicted_semantics)

    # Calculate true positives, false positives, and false negatives
    true_positives = len(gold_set.intersection(predicted_set))
    false_positives = len(predicted_set - gold_set)
    false_negatives = len(gold_set - predicted_set)
    print(f"Wrong: {str(predicted_set - gold_set)}")

    # Calculate precision and recall
    if len(predicted_set) == 0 and len(gold_set) == 0:
        precision = 1
        recall = 1
    else:
        precision = true_positives / (len(predicted_set)) if (true_positives + false_positives) > 0 else 0
        recall = true_positives / len(gold_set) if (true_positives + false_negatives) > 0 else 0
    return precision, recall

# %%
gold_list = [
    "/root/autodl-tmp/semantic_labeling/data/soccer/models_triples_json/s11-world-cup-player-ages-model.json",
    "/root/autodl-tmp/semantic_labeling/data/soccer/models_triples_json/s09-world-cup-2010-squads-model.json",
    "/root/autodl-tmp/semantic_labeling/data/soccer/models_triples_json/s06-players-model.json",
    "/root/autodl-tmp/semantic_labeling/data/soccer/models_triples_json/s12-world-cup-squads-model.json",
    "/root/autodl-tmp/semantic_labeling/data/soccer/models_triples_json/s08-WM-2014-Alle-Spieler-players-fifa-model.json",
    "/root/autodl-tmp/semantic_labeling/data/soccer/models_triples_json/s07-uefa-players-model.json"
]
pre = []
rec = []

# %%
for i, j in enumerate(gold_list):  
    gold_semantics = load_json(j)['semantic_triples']
    predicted_semantics = [i.replace('\'', '').split(", ") for i in step1_list[i][2:-2].split("],\n[")]
    print(gold_semantics)
    print(predicted_semantics)
    precision, recall = calculate_precision_recall(gold_semantics, predicted_semantics)
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    pre.append(precision)
    rec.append(recall)
print(f"Mean Precision: {sum(pre) / len(pre)}")
print(f"Mean Recall: {sum(rec) / len(rec)}")
# Out:
# [['schema:Player1', 'schema:age', 'Age'], ['schema:Player1', 'schema:tag', 'Number'], ['schema:Player1', 'schema:playPosition', 'Position'], ['schema:Player1', 'schema:name', 'Player'], ['schema:SportsTeam1', 'schema:name', 'Country']]
# [['schema:Player1', 'schema:age', 'Age'], ['schema:Player1', 'schema:tag', 'Number'], ['schema:Player1', 'schema:playPosition', 'Position'], ['schema:Player1', 'schema:name', 'Player'], ['schema:Place1', 'schema:name', 'Country']]
# Wrong: {('schema:Place1', 'schema:name', 'Country')}
# Precision: 0.8
# Recall: 0.8
# [['schema:Player1', 'schema:alternateName', 'Shirt Name'], ['schema:Player1', 'schema:birthDate', 'Date of Birth'], ['schema:Player1', 'schema:familyName', 'Last Name'], ['schema:Player1', 'schema:givenName', 'First Name'], ['schema:Player1', 'schema:name', 'FIFA Display Name'], ['schema:SportsTeam1', 'schema:name', 'Country'], ['schema:Player1', 'schema:height', 'Height'], ['schema:Player1', 'schema:tag', 'No.'], ['schema:Player1', 'schema:playPosition', 'Position'], ['schema:SportsClub1', 'schema:name', 'Club'], ['schema:League1', 'schema:name', 'Club (Country)']]
# [['schema:Player1', 'schema:alternateName', 'Shirt Name'], ['schema:Player1', 'schema:birthDate', 'Date of Birth'], ['schema:Player1', 'schema:familyName', 'Last Name'], ['schema:Player1', 'schema:givenName', 'First Name'], ['schema:Player1', 'schema:name', 'FIFA Display Name'], ['schema:Player1', 'schema:birthPlace', 'Country'], ['schema:Player1', 'schema:height', 'Height'], ['schema:Player1', 'schema:tag', 'No.'], ['schema:Player1', 'schema:playPosition', 'Position'], ['schema:SportsClub1', 'schema:name', 'Club'], ['schema:SportsClub1', 'schema:birthPlace', 'Club (Country)']]
# Wrong: {('schema:Player1', 'schema:birthPlace', 'Country'), ('schema:SportsClub1', 'schema:birthPlace', 'Club (Country)')}
# Precision: 0.8181818181818182
# Recall: 0.8181818181818182
# [['schema:Player1', 'schema:name', 'displayName'], ['schema:Player1', 'schema:givenName', 'firstName'], ['schema:Player1', 'schema:familyName', 'lastName'], ['schema:Player1', 'schema:name', 'fullName'], ['schema:Player1', 'schema:alternateName', 'shortName'], ['schema:League1', 'schema:name', 'leagueName'], ['schema:League1', 'schema:name', 'leagueShortname']]
# [['schema:Person1', 'schema:displayName', 'displayName'], ['schema:Person1', 'schema:givenName', 'firstName'], ['schema:Person1', 'schema:familyName', 'lastName'], ['schema:Person1', 'schema:name', 'fullName'], ['schema:Person1', 'schema:alternateName', 'shortName'], ['schema:League1', 'schema:name', 'leagueName'], ['schema:League1', 'schema:alternateName', 'leagueShortname']]
# Wrong: {('schema:Person1', 'schema:displayName', 'displayName'), ('schema:League1', 'schema:alternateName', 'leagueShortname'), ('schema:Person1', 'schema:name', 'fullName'), ('schema:Person1', 'schema:familyName', 'lastName'), ('schema:Person1', 'schema:alternateName', 'shortName'), ('schema:Person1', 'schema:givenName', 'firstName')}
# Precision: 0.14285714285714285
# Recall: 0.14285714285714285
# [['schema:Player1', 'schema:tag', 'Number'], ['schema:SportsTeam1', 'schema:name', 'Team'], ['schema:Player1', 'schema:name', 'FullName'], ['schema:Player1', 'schema:playPosition', 'Position'], ['schema:League1', 'schema:name', 'ClubCountry'], ['schema:SportsClub1', 'schema:name', 'Club'], ['schema:Player1', 'schema:isCaptain', 'IsCaptain'], ['schema:Player1', 'schema:birthDate', 'DateOfBirth']]
# [['schema:Player1', 'schema:tag', 'Number'], ['schema:Player1', 'schema:name', 'FullName'], ['schema:Player1', 'schema:playPosition', 'Position'], ['schema:Player1', 'schema:birthDate', 'DateOfBirth'], ['schema:SportsClub1', 'schema:name', 'Club'], ['schema:SportsClub1', 'schema:alternateName', 'ClubCountry'], ['schema:Player1', 'schema:isCaptain', 'IsCaptain']]
# Wrong: {('schema:SportsClub1', 'schema:alternateName', 'ClubCountry')}
# Precision: 0.8571428571428571
# Recall: 0.75
# [['schema:Player1', 'schema:playPosition', 'Position'], ['schema:Player1', 'schema:name', 'Player'], ['schema:SportsTeam1', 'schema:name', 'Country'], ['schema:Player1', 'schema:height', 'Height'], ['schema:Player1', 'schema:age', 'Age'], ['schema:Player1', 'schema:birthDate', 'D.O.B'], ['schema:Player1', 'schema:numberOfPlayedGames', 'Caps'], ['schema:Player1', 'schema:goalScored', 'International goals'], ['schema:League1', 'schema:name', 'Club (country)'], ['schema:SportsClub1', 'schema:name', 'Club'], ['schema:Player1', 'schema:tag', 'Number']]
# [['schema:Player1', 'schema:playPosition', 'Position'], ['schema:Player1', 'schema:name', 'Player'], ['schema:Player1', 'schema:birthPlace', 'Country'], ['schema:Player1', 'schema:height', 'Height'], ['schema:Player1', 'schema:age', 'Age'], ['schema:Player1', 'schema:birthDate', 'D.O.B'], ['schema:Player1', 'schema:numberOfPlayedGames', 'Caps'], ['schema:Player1', 'schema:goalScored', 'International goals'], ['schema:SportsClub1', 'schema:name', 'Club'], ['schema:Player1', 'schema:tag', 'Number']]
# Wrong: {('schema:Player1', 'schema:birthPlace', 'Country')}
# Precision: 0.9
# Recall: 0.8181818181818182
# [['schema:Player1', 'schema:givenName', 'fn'], ['schema:Player1', 'schema:familyName', 'ln'], ['schema:League1', 'schema:name', 'cn'], ['schema:Player1', 'schema:age', 'ag'], ['schema:Player1', 'schema:name', 'sn'], ['schema:Player1', 'schema:height', 'ht'], ['schema:SportsClub1', 'schema:name', 'cb'], ['schema:Player1', 'schema:playPosition', 'ps'], ['schema:Player1', 'schema:tag', 'no'], ['schema:Player1', 'schema:birthDate', 'db'], ['schema:Player1', 'schema:goalScored', 'go/at'], ['schema:SportsTeam1', 'schema:name', 'nt']]
# [['schema:Player1', 'schema:givenName', 'fn'], ['schema:Player1', 'schema:familyName', 'ln'], ['schema:Player1', 'schema:nationality', 'cn'], ['schema:Player1', 'schema:age', 'ag'], ['schema:Player1', 'schema:alternateName', 'sn'], ['schema:Player1', 'schema:height', 'ht'], ['schema:SportsClub1', 'schema:name', 'cb'], ['schema:Player1', 'schema:playPosition', 'ps'], ['schema:Player1', 'schema:number', 'no'], ['schema:Player1', 'schema:birthDate', 'db'], ['schema:Player1', 'schema:goalScored', 'go/at'], ['schema:SportsTeam1', 'schema:alternateName', 'nt']]
# Wrong: {('schema:Player1', 'schema:alternateName', 'sn'), ('schema:Player1', 'schema:nationality', 'cn'), ('schema:Player1', 'schema:number', 'no'), ('schema:SportsTeam1', 'schema:alternateName', 'nt')}
# Precision: 0.6666666666666666
# Recall: 0.6666666666666666
# Mean Precision: 0.6974747474747475
# Mean Recall: 0.665981240981241

# %%
import re

# Read the file content
with open('/root/autodl-tmp/semantic_labeling/exp_2023/1-shot-results/soccer_gpt_4_turbo/5.txt', 'r') as file:
    content = file.read()

# Use regex to find all <Step2> sections
step2_sections = re.findall(r'<Step2>(.*?)</Step2>', content, re.DOTALL)

# Store the extracted sections in a list
step2_list = [section.strip() for section in step2_sections]

# Print the list to verify
print(step2_list)
# Out:
# ["[['schema:Player1', 'schema:birthPlace', 'schema:Place1']]", "[['schema:Player1', 'schema:inClub', 'schema:SportsClub1']]", "[['schema:Person1', 'schema:inLeague', 'schema:League1']]", "[['schema:Player1', 'schema:inClub', 'schema:SportsClub1']]", "[['schema:Player1', 'schema:inClub', 'schema:SportsClub1']]", "[['schema:Player1', 'schema:inClub', 'schema:SportsClub1'],\n['schema:Player1', 'schema:inNationalTeam', 'schema:SportsTeam1']]"]

# %%
for i, j in enumerate(gold_list):  
    gold_semantics = load_json(j)['internal_link_triples']
    predicted_semantics = [i.replace('\'', '').split(", ") for i in step2_list[i][2:-2].split("],\n[")]
    print(gold_semantics)
    print(predicted_semantics)
    precision, recall = calculate_precision_recall(gold_semantics, predicted_semantics)
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    pre.append(precision)
    rec.append(recall)
print(f"Mean Precision: {sum(pre) / len(pre)}")
print(f"Mean Recall: {sum(rec) / len(rec)}")
# Out:
# [['schema:Player1', 'schema:inNationalTeam', 'schema:SportsTeam1']]
# [['schema:Player1', 'schema:birthPlace', 'schema:Place1']]
# Wrong: {('schema:Player1', 'schema:birthPlace', 'schema:Place1')}
# Precision: 0.0
# Recall: 0.0
# [['schema:Player1', 'schema:inClub', 'schema:SportsClub1'], ['schema:Player1', 'schema:inNationalTeam', 'schema:SportsTeam1'], ['schema:SportsClub1', 'schema:inLeague', 'schema:League1']]
# [['schema:Player1', 'schema:inClub', 'schema:SportsClub1']]
# Wrong: set()
# Precision: 1.0
# Recall: 0.3333333333333333
# [['schema:Player1', 'schema:inClub', 'schema:SportsClub1'], ['schema:SportsClub1', 'schema:inLeague', 'schema:League1']]
# [['schema:Person1', 'schema:inLeague', 'schema:League1']]
# Wrong: {('schema:Person1', 'schema:inLeague', 'schema:League1')}
# Precision: 0.0
# Recall: 0.0
# [['schema:Player1', 'schema:inClub', 'schema:SportsClub1'], ['schema:Player1', 'schema:inNationalTeam', 'schema:SportsTeam1'], ['schema:SportsClub1', 'schema:inLeague', 'schema:League1']]
# [['schema:Player1', 'schema:inClub', 'schema:SportsClub1']]
# Wrong: set()
# Precision: 1.0
# Recall: 0.3333333333333333
# [['schema:Player1', 'schema:inClub', 'schema:SportsClub1'], ['schema:Player1', 'schema:inNationalTeam', 'schema:SportsTeam1'], ['schema:SportsClub1', 'schema:inLeague', 'schema:League1']]
# [['schema:Player1', 'schema:inClub', 'schema:SportsClub1']]
# Wrong: set()
# Precision: 1.0
# Recall: 0.3333333333333333
# [['schema:Player1', 'schema:inClub', 'schema:SportsClub1'], ['schema:Player1', 'schema:inNationalTeam', 'schema:SportsTeam1'], ['schema:SportsClub1', 'schema:inLeague', 'schema:League1']]
# [['schema:Player1', 'schema:inClub', 'schema:SportsClub1'], ['schema:Player1', 'schema:inNationalTeam', 'schema:SportsTeam1']]
# Wrong: set()
# Precision: 1.0
# Recall: 0.6666666666666666
# Mean Precision: 0.6872053872053872
# Mean Recall: 0.5365800865800866
