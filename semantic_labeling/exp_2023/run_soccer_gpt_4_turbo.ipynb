# %%
from data_loader import generate_data
from instruct_prompt_generator import load_ontologies
from openai import OpenAI

train_path = "/root/autodl-tmp/semantic_labeling/data/soccer/tables_sources_json/"
models_path = "/root/autodl-tmp/semantic_labeling/data/soccer/models_triples_json/"
ontology_path = "/root/autodl-tmp/semantic_labeling/data/soccer/ontology/Ontologies.json"

train_data, test_data = generate_data(train_path, models_path,  12, 3, 0.5, 2023)
ontology = load_ontologies(ontology_path)
prompt_path = "/root/autodl-tmp/semantic_labeling/exp_2023/prompt123.txt"
chain_path1 = "/root/autodl-tmp/semantic_labeling/exp_2023/chain1.txt"
chain_path2 = "/root/autodl-tmp/semantic_labeling/exp_2023/chain2.txt"

from Prompt_Reason_gpt_4_turbo import generate_reason
sample_size = 1
for i in range(sample_size):
  model = OpenAI(
      api_key="sk-0Q2S5T9j8Dcg2ytgeJaygrX9HRbT7OKnpfR36iuctZXW9m39",
      base_url="https://api.claudeshop.top/v1"
  )
  print(f'This is epoch {i}')
  generate_reason(train_data, ontology, test_data, prompt_path, chain_path1, chain_path2, model)
  print("=========================================")
# Out:
# Loading data from [0, 1, 2, 3, 4, 5] files
# Loading data from /root/autodl-tmp/semantic_labeling_2023/data/soccer/tables_sources_json/s05-mls-players-2015.json and /root/autodl-tmp/semantic_labeling_2023/data/soccer/models_triples_json/s05-mls-players-2015-model.json
# Loading data from /root/autodl-tmp/semantic_labeling_2023/data/soccer/tables_sources_json/s02-all-world-cup-players.json and /root/autodl-tmp/semantic_labeling_2023/data/soccer/models_triples_json/s02-all-world-cup-players-model.json
# Loading data from /root/autodl-tmp/semantic_labeling_2023/data/soccer/tables_sources_json/s04-fifa-soccer-12-ultimate-team-data-player-database.json and /root/autodl-tmp/semantic_labeling_2023/data/soccer/models_triples_json/s04-fifa-soccer-12-ultimate-team-data-player-database-model.json
# Loading data from /root/autodl-tmp/semantic_labeling_2023/data/soccer/tables_sources_json/s03-bundesliga-2015-2016-rosters.json and /root/autodl-tmp/semantic_labeling_2023/data/soccer/models_triples_json/s03-bundesliga-2015-2016-rosters-model.json
# Loading data from /root/autodl-tmp/semantic_labeling_2023/data/soccer/tables_sources_json/s10-world-cup-2014-squads.json and /root/autodl-tmp/semantic_labeling_2023/data/soccer/models_triples_json/s10-world-cup-2014-squads-model.json
# Loading data from /root/autodl-tmp/semantic_labeling_2023/data/soccer/tables_sources_json/s01-2014-WC-fresh.json and /root/autodl-tmp/semantic_labeling_2023/data/soccer/models_triples_json/s01-2014-WC-fresh-model.json
# Loading data from [6, 7, 8, 9, 10, 11] files
# Loading data from /root/autodl-tmp/semantic_labeling_2023/data/soccer/tables_sources_json/s11-world-cup-player-ages.json and /root/autodl-tmp/semantic_labeling_2023/data/soccer/models_triples_json/s11-world-cup-player-ages-model.json
# Loading data from /root/autodl-tmp/semantic_labeling_2023/data/soccer/tables_sources_json/s09-world-cup-2010-squads.json and /root/autodl-tmp/semantic_labeling_2023/data/soccer/models_triples_json/s09-world-cup-2010-squads-model.json
# Loading data from /root/autodl-tmp/semantic_labeling_2023/data/soccer/tables_sources_json/s06-players.json and /root/autodl-tmp/semantic_labeling_2023/data/soccer/models_triples_json/s06-players-model.json
# Loading data from /root/autodl-tmp/semantic_labeling_2023/data/soccer/tables_sources_json/s12-world-cup-squads.json and /root/autodl-tmp/semantic_labeling_2023/data/soccer/models_triples_json/s12-world-cup-squads-model.json
# Loading data from /root/autodl-tmp/semantic_labeling_2023/data/soccer/tables_sources_json/s08-WM-2014-Alle-Spieler-players-fifa.json and /root/autodl-tmp/semantic_labeling_2023/data/soccer/models_triples_json/s08-WM-2014-Alle-Spieler-players-fifa-model.json
# Loading data from /root/autodl-tmp/semantic_labeling_2023/data/soccer/tables_sources_json/s07-uefa-players.json and /root/autodl-tmp/semantic_labeling_2023/data/soccer/models_triples_json/s07-uefa-players-model.json
# This is epoch 0
# Enter value for variable: $TABLE
# Enter value for variable: $ONTOLOGY
# Enter value for variable: $STEP1
# Enter value for variable: $STEP2
# [['schema:Player1', 'schema:inNationalTeam', 'schema:SportsTeam1']]
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# [['schema:Player1', 'schema:inClub', 'schema:SportsClub1'], ['schema:SportsClub1', 'schema:inLeague', 'schema:ClubCountry']]
# Wrong: {('schema:SportsClub1', 'schema:inLeague', 'schema:ClubCountry')}
# Precision: 0.5
# Recall: 0.3333333333333333
# [['']]
# Wrong: {('',)}
# Precision: 0.0
# Recall: 0.0
# [['schema:Player1', 'schema:inClub', 'schema:SportsClub1'], ['schema:Player1', 'schema:inNationalTeam', 'schema:SportsTeam1'], ['schema:SportsClub1', 'schema:inLeague', 'schema:League1']]
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# [['schema:Player1', 'schema:inNationalTeam', 'schema:SportsTeam1'], ['schema:Player1', 'schema:inClub', 'schema:SportsClub1'], ['schema:SportsClub1', 'schema:inLeague', 'schema:League1']]
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# [['schema:Player1', 'schema:inNationalTeam', 'schema:SportsTeam1]', '\n [schema:Player1', 'schema:inClub', 'schema:SportsClub1']]
# Wrong: {('schema:Player1', 'schema:inNationalTeam', 'schema:SportsTeam1]', '\n [schema:Player1', 'schema:inClub', 'schema:SportsClub1')}
# Precision: 0.0
# Recall: 0.0
# Mean Precision: 0.5833333333333334
# Mean Recall: 0.5555555555555555
# =========================================
