# %%
import re

# Read the file content
with open('gpt-4-turbo-edm/13.txt', 'r') as file:
    content = file.read()

# Use regex to find all <Step2> sections
step1_sections = re.findall(r'<Step1>(.*?)</Step1>', content, re.DOTALL)

# Store the extracted sections in a list
step1_list = [section.strip() for section in step1_sections]

# Print the list to verify
print(step1_list)
# Out:
# ["[['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'name'],\n['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'],\n['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'],\n['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate']]", "[['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'],\n['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'name'],\n['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'],\n['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'],\n['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate']]", "[['edm:WebResource1', 'karma:classLink', 'photo'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'dimensions'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:medium', 'technique'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'credittext'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:created', 'artyear'],\n['foaf:Document1', 'karma:classLink', 'link'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:description', 'artdesc'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'],\n['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'artist'],\n['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'],\n['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'artistBirth'],\n['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'artistDeath']]", '[["aac-ont:CulturalHeritageObject1", "dcterms:description", "description"],\n["aac-ont:CulturalHeritageObject1", "dcterms:title", "title"],\n["aac-ont:Person1", "ElementsGr2:nameOfThePerson", "artist"],\n["skos:Collection1", "skos:member", "subjectTags"],\n["aac-ont:CulturalHeritageObject1", "dcterms:provenance", "credit"],\n["aac-ont:CulturalHeritageObject1", "dcterms:medium", "materials"],\n["edm:WebResource1", "karma:classLink", "imageURL"],\n["aac-ont:CulturalHeritageObject1", "aac-ont:accessionNumber", "accessionID"],\n["aac-ont:CulturalHeritageObject1", "dcterms:created", "dateCreated"],\n["aac-ont:CulturalHeritageObject1", "dcterms:extent", "dimensions"],\n["aac-ont:CulturalHeritageObject1", "dcterms:method", "techniqueType"]]', "[['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'idNumber'],\n['skos:Concept1', 'skos:prefLabel', 'category'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'],\n['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'maker'],\n['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'makerBioCountry'],\n['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'],\n['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate'],\n['aac-ont:Place1', 'rdfs:label', 'placeMade'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:medium', 'materials'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'measurements'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:description', 'description'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'creditLine'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:rightsHolder', 'owner'],\n['skos:Concept2', 'skos:prefLabel', 'option'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:created', 'createDate']]", "[['aac-ont:CulturalHeritageObject1', 'dcterms:title', 'title'],\n['foaf:Document1', 'karma:classLink', 'sourceURL'],\n['edm:WebResource1', 'karma:classLink', 'imageURL'],\n['aac-ont:Person1', 'ElementsGr2:nameOfThePerson', 'artist'],\n['aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'nationality'],\n['aac-ont:Person1', 'ElementsGr2:dateOfBirth', 'birthDate'],\n['aac-ont:Person1', 'ElementsGr2:dateOfDeath', 'deathDate'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:created', 'creationDate'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:medium', 'materials'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:extent', 'dimensions'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:provenance', 'creditLine'],\n['aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'accessionNumber'],\n['aac-ont:CulturalHeritageObject1', 'dcterms ...

# %%
import json

def load_json(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)
def calculate_precision_recall(gold_semantics, predicted_semantics):
    
    gold_set = set(tuple(item) for item in gold_semantics)
    predicted_set = set(tuple(item) for item in predicted_semantics)

    # Calculate true positives, false positives, and false negatives
    true_positives = len(gold_set.intersection(predicted_set))
    false_positives = len(predicted_set - gold_set)
    false_negatives = len(gold_set - predicted_set)
    print(f"Wrong: {str(predicted_set - gold_set)}")

    # Calculate precision and recall
    if len(predicted_set) == 1 and len(predicted_set) == 0 and len(gold_set) == 0:
        precision = 1
        recall = 1
    else:
        precision = true_positives / (len(predicted_set)) if (true_positives + false_positives) > 0 else 0
        recall = true_positives / len(gold_set) if (true_positives + false_negatives) > 0 else 0
    return precision, recall

# %%
gold_list = [
    "edm-data/models_triples_json/s03-ima-artists-model.json",
    "edm-data/models_triples_json/s18-s-indianapolis-artists-model.json",
    "edm-data/models_triples_json/s17-s-houston-museum-of-fine-arts-model.json",
    "edm-data/models_triples_json/s10-s-18-artworks-model.json",
    "edm-data/models_triples_json/s27-wildlife-art-model.json",
    "edm-data/models_triples_json/s04-ima-artworks-model.json",
    "edm-data/models_triples_json/s24-s-oakland-museum-paintings-model.json",
    "edm-data/models_triples_json/s19-s-indianapolis-artworks-model.json",
    "edm-data/models_triples_json/s20-s-lacma-model.json",
    "edm-data/models_triples_json/s11-s-19-artists-model.json",
    "edm-data/models_triples_json/s28-gilcrease-model.json",
    "edm-data/models_triples_json/s15-s-detroit-institute-of-art-model.json",
    "edm-data/models_triples_json/s23-s-norton-simon-model.json",
    "edm-data/models_triples_json/s13-s-art-institute-of-chicago-model.json"
]
pre = []
rec = []

# %%
for i, j in enumerate(gold_list):  
    gold_semantics = load_json(j)['semantic_triples']
    predicted_semantics = [i.replace('\'', '').split(", ") for i in step1_list[i][2:-2].split("],\n[")]
    precision, recall = calculate_precision_recall(gold_semantics, predicted_semantics)
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    pre.append(precision)
    rec.append(recall)
print(f"Mean Precision: {sum(pre) / len(pre)}")
print(f"Mean Recall: {sum(rec) / len(rec)}")
# Out:
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# Wrong: {('"aac-ont:CulturalHeritageObject1"', '"dcterms:extent"', '"dimensions"'), ('"aac-ont:CulturalHeritageObject1"', '"dcterms:medium"', '"materials"'), ('"aac-ont:CulturalHeritageObject1"', '"dcterms:created"', '"dateCreated"'), ('"aac-ont:CulturalHeritageObject1"', '"dcterms:method"', '"techniqueType"'), ('"edm:WebResource1"', '"karma:classLink"', '"imageURL"'), ('"aac-ont:CulturalHeritageObject1"', '"dcterms:title"', '"title"'), ('"aac-ont:Person1"', '"ElementsGr2:nameOfThePerson"', '"artist"'), ('"aac-ont:CulturalHeritageObject1"', '"dcterms:description"', '"description"'), ('"skos:Collection1"', '"skos:member"', '"subjectTags"'), ('"aac-ont:CulturalHeritageObject1"', '"dcterms:provenance"', '"credit"'), ('"aac-ont:CulturalHeritageObject1"', '"aac-ont:accessionNumber"', '"accessionID"')}
# Precision: 0.0
# Recall: 0.0
# Wrong: {('skos:Concept2', 'skos:prefLabel', 'option'), ('skos:Concept1', 'skos:prefLabel', 'category'), ('aac-ont:Person1', 'ElementsGr2:countryAssociatedWithThePerson', 'makerBioCountry')}
# Precision: 0.8
# Recall: 0.8
# Wrong: {('edm:WebResource2', 'karma:classLink', 'relatedArtworksURL')}
# Precision: 0.9411764705882353
# Recall: 0.9411764705882353
# Wrong: {('aac-ont:CulturalHeritageObject1', 'dcterms:note', 'inscription'), ('skos:Concept1', 'skos:prefLabel', 'typeOfArt')}
# Precision: 0.8461538461538461
# Recall: 0.8461538461538461
# Wrong: {('edm:WebResource2', 'karma:classLink', 'relatedArtworksURL')}
# Precision: 0.9411764705882353
# Recall: 0.9411764705882353
# Wrong: {('aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'ID')}
# Precision: 0.8888888888888888
# Recall: 0.8888888888888888
# Wrong: {('skos:Concept1', 'skos:prefLabel', 'occupation')}
# Precision: 0.8333333333333334
# Recall: 0.8333333333333334
# Wrong: {('aac-ont:CulturalHeritageObject1', 'aac-ont:accessionNumber', 'objectID'), ('aac-ont:CulturalHeritageObject1', 'aac-ont:objectId', 'objectNumber')}
# Precision: 0.7777777777777778
# Recall: 0.7777777777777778
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# Wrong: {('skos:Concept1', 'skos:prefLabel', 'typeofartwork')}
# Precision: 0.9
# Recall: 0.9
# Mean Precision: 0.8520361990950228
# Mean Recall: 0.8520361990950228

# %%
import re

# Read the file content
with open('gpt-4-turbo-edm/13.txt', 'r') as file:
    content = file.read()

# Use regex to find all <Step2> sections
step2_sections = re.findall(r'<Step2>(.*?)</Step2>', content, re.DOTALL)

# Store the extracted sections in a list
step2_list = [section.strip() for section in step2_sections]

# Print the list to verify
print(step2_list)
# Out:
# ['[]', "[['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1']]", "[['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'],\n['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'],\n['aac-ont:CulturalHeritageObject1', 'foaf:page', 'foaf:Document1']]", '[["edm:EuropeanaAggregation1", "edm:aggregatedCHO", "aac-ont:CulturalHeritageObject1"],\n["edm:EuropeanaAggregation1", "edm:hasView", "edm:WebResource1"],\n["aac-ont:CulturalHeritageObject1", "dcterms:creator", "aac-ont:Person1"],\n["aac-ont:CulturalHeritageObject1", "dcterms:subject", "skos:Concept1"],    \n["skos:Collection1", "skos:member", "skos:Concept1"],\n["aac-ont:CulturalHeritageObject1", "dcterms:medium", "skos:Concept2"],\n["aac-ont:CulturalHeritageObject1", "dcterms:hasFormat", "skos:Concept3"]]', "[['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'],\n['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1'],\n['aac-ont:Person1', 'ElementsGr2:placeOfBirth', 'aac-ont:Place1'],\n['skos:Concept1', 'skos:related', 'skos:Concept2']]", "[['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'],\n['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1'],\n['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource2'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'],\n['aac-ont:CulturalHeritageObject1', 'edm:isRelatedTo', 'aac-ont:CulturalHeritageObject2'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:subject', 'skos:Concept1']]", "[['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'],\n['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'],\n['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1'],\n['aac-ont:CulturalHeritageObject1', 'dc:subject', 'skos:Concept1']]", "[['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'],\n['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'],\n['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1'],\n['aac-ont:CulturalHeritageObject1', 'edm:isRelatedTo', 'aac-ont:CulturalHeritageObject2'],\n['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource2'],\n['aac-ont:CulturalHeritageObject1', 'skos:related', 'aac-ont:CulturalHeritageObject2']]", "[['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:isVersionOf', 'aac-ont:CulturalHeritageObject2']]", "[['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'],\n['aac-ont:Person1', 'dcterms:subject', 'skos:Concept1']]", "[['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'],\n['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'],\n['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1']]", "[['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'],\n['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'],\n['aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1']]", "[['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'],\n['edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1'],\n['aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1']]", "[['edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'],\n['edm:EuropeanaAggregation1', 'edm ...

# %%
for i, j in enumerate(gold_list):  
    gold_semantics = load_json(j)['internal_link_triples']
    predicted_semantics = [i.replace('\'', '').split(", ") for i in step2_list[i][2:-2].split("],\n[")]
    precision, recall = calculate_precision_recall(gold_semantics, predicted_semantics)
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    pre.append(precision)
    rec.append(recall)
print(f"Mean Precision: {sum(pre) / len(pre)}")
print(f"Mean Recall: {sum(rec) / len(rec)}")
# Out:
# Wrong: {('',)}
# Precision: 0.0
# Recall: 0
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# Wrong: {('"edm:EuropeanaAggregation1"', '"edm:hasView"', '"edm:WebResource1"'), ('"aac-ont:CulturalHeritageObject1"', '"dcterms:creator"', '"aac-ont:Person1"'), ('"aac-ont:CulturalHeritageObject1"', '"dcterms:hasFormat"', '"skos:Concept3"'), ('"aac-ont:CulturalHeritageObject1"', '"dcterms:medium"', '"skos:Concept2"'), ('"edm:EuropeanaAggregation1"', '"edm:aggregatedCHO"', '"aac-ont:CulturalHeritageObject1"'), ('"aac-ont:CulturalHeritageObject1"', '"dcterms:subject"', '"skos:Concept1"]', '   \n["skos:Collection1"', '"skos:member"', '"skos:Concept1"')}
# Precision: 0.0
# Recall: 0.0
# Wrong: {('aac-ont:Person1', 'ElementsGr2:placeOfBirth', 'aac-ont:Place1'), ('aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1'), ('edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1'), ('skos:Concept1', 'skos:related', 'skos:Concept2')}
# Precision: 0.2
# Recall: 0.25
# Wrong: {('edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource2')}
# Precision: 0.8333333333333334
# Recall: 0.7142857142857143
# Wrong: {('aac-ont:CulturalHeritageObject1', 'dc:subject', 'skos:Concept1'), ('aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1')}
# Precision: 0.6
# Recall: 0.6
# Wrong: {('aac-ont:CulturalHeritageObject1', 'skos:related', 'aac-ont:CulturalHeritageObject2'), ('aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1'), ('edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource2')}
# Precision: 0.5714285714285714
# Recall: 0.5714285714285714
# Wrong: {('aac-ont:CulturalHeritageObject1', 'dcterms:isVersionOf', 'aac-ont:CulturalHeritageObject2')}
# Precision: 0.6666666666666666
# Recall: 0.6666666666666666
# Wrong: {('aac-ont:CulturalHeritageObject1', 'dcterms:creator', 'aac-ont:Person1'), ('aac-ont:Person1', 'dcterms:subject', 'skos:Concept1')}
# Precision: 0.0
# Recall: 0
# Wrong: {('edm:EuropeanaAggregation1', 'edm:hasView', 'edm:WebResource1'), ('edm:EuropeanaAggregation1', 'edm:aggregatedCHO', 'aac-ont:CulturalHeritageObject1')}
# Precision: 0.5
# Recall: 1.0
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# Wrong: {('aac-ont:CulturalHeritageObject1', 'edm:hasType', 'skos:Concept1')}
# Precision: 0.75
# Recall: 1.0
# Mean Precision: 0.7160691199556747
# Mean Recall: 0.7403888478468311
