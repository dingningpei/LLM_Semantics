# %%
import re

# Read the file content
with open('gpt-4o-mini-crm/13.txt', 'r') as file:
    content = file.read()

# Use regex to find all <Step2> sections
step1_sections = re.findall(r'<Step1>(.*?)</Step1>', content, re.DOTALL)

# Store the extracted sections in a list
step1_list = [section.strip() for section in step1_sections]

# Print the list to verify
print(step1_list)
# Out:
# ["[['crm:E35_Title1', 'rdfs:label', 'title'],\n['crm:E82_Actor_Appellation1', 'rdfs:label', 'name'],\n['crm:E74_Group1', 'rdfs:label', 'nationality'],\n['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'],\n['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate']]", "[['crm:E35_Title1', 'rdfs:label', 'title'],\n['crm:E82_Actor_Appellation1', 'rdfs:label', 'name'],\n['crm:E74_Group1', 'rdfs:label', 'nationality'],\n['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'],\n['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate']]", "[['crm:E35_Title1', 'rdfs:label', 'title'],\n['crm:E38_Image1', 'karma:classLink', 'photo'],\n['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions'],\n['crm:E55_Type1', 'rdfs:label', 'technique'],\n['crm:E8_Acquisition1', 'crm:P3_has_note', 'credittext'],\n['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'artyear'],\n['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'artdesc'],\n['crm:E82_Actor_Appellation1', 'rdfs:label', 'artist'],\n['crm:E74_Group1', 'rdfs:label', 'nationality'],\n['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'artistBirth'],\n['crm:E52_Time-Span3', 'crm:P82_at_some_time_within', 'artistDeath']]", "[['crm:E22_Man-Made_Object1', 'rdfs:label', 'collectionURL'],\n['crm:E13_Attribute_Assignment1', 'crm:P3_has_note', 'inscription'],\n['crm:E8_Acquisition1', 'crm:P3_has_note', 'description'],\n['crm:E35_Title1', 'rdfs:label', 'title'],\n['crm:E78_Collection1', 'rdfs:label', 'collectionName'],\n['crm:E82_Actor_Appellation1', 'rdfs:label', 'artist'],\n['crm:E8_Acquisition1', 'crm:P3_has_note', 'credit'],\n['crm:E55_Type1', 'rdfs:label', 'materials'],\n['crm:E38_Image1', 'karma:classLink', 'imageURL'],\n['crm:E53_Place1', 'crm:P4_has_time-span', 'placeAndDataMade'],\n['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions']]", "[['crm:E55_Type1', 'rdfs:label', 'category'],\n['crm:E35_Title1', 'rdfs:label', 'title'],\n['crm:E82_Actor_Appellation1', 'rdfs:label', 'maker'],\n['crm:E44_Place_Appellation1', 'rdfs:label', 'makerBioCountry'],\n['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'],\n['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate'],\n['crm:E78_Collection1', 'crm:P3_has_note', 'collector'],\n['crm:E53_Place1', 'crm:P7_took_place_at', 'placeMade'],\n['crm:E18_Physical_Thing1', 'crm:P3_has_note', 'materials'],\n['crm:E54_Dimension1', 'crm:P3_has_note', 'measurements'],\n['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'description'],\n['crm:E78_Collection1', 'crm:P3_has_note', 'creditLine'],\n['crm:E78_Collection1', 'crm:P51_has_former_or_current_owner', 'owner'],\n['crm:E8_Acquisition1', 'crm:P3_has_note', 'howAcquired']]", "[['crm:E35_Title1', 'rdfs:label', 'title'],\n['crm:E82_Actor_Appellation1', 'rdfs:label', 'artist'],\n['crm:E74_Group1', 'rdfs:label', 'nationality'],\n['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'],\n['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate'],\n['crm:E52_Time-Span3', 'crm:P82_at_some_time_within', 'creationDate'],\n['crm:E55_Type2', 'rdfs:label', 'materials'],\n['crm:E54_Dimension1', 'crm:P3_has_note', 'dimensions'],\n['crm:E31_Document1', 'karma:classLink', 'sourceURL'],\n['crm:E38_Image1', 'karma:classLink', 'imageURL'],\n['crm:E8_Acquisition1', 'crm:P3_has_note', 'creditLine'],\n['crm:E8_Acquisition1', 'crm:P3_has_note', 'galleryLabel'],\n['crm:E8_Acquisition1', 'crm:P3_has_note', 'provenance']]", "[['crm:E82_Actor_Appellation1', 'rdfs:label', 'artistName'],\n['crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDate'],\n['crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'deathDate'],\n['crm:E55_Type1', 'rdfs:label', 'subtypeOfArt'],\n['crm:E55_Type1', 'rdfs:label', 'typeOfArt'],\n['crm:E35_Title1', 'rdfs:label', 'title'],\n['crm:E52_Time-Span4', 'crm:P82_at_some_time_within', 'dateMade'],\n['crm:E8_Acquisition1', 'crm:P3_has_note', 'credit'],\n['crm:E33_Linguistic_Object1', 'crm:P3_has_note', 'inscription'],\n['crm:E38_Imag ...

# %%
import json

def load_json(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)
def calculate_precision_recall(gold_semantics, predicted_semantics):
    
    gold_set = set(tuple(item) for item in gold_semantics)
    predicted_set = set(tuple(item) for item in predicted_semantics)

    # Calculate true positives, false positives, and false negatives
    true_positives = len(gold_set.intersection(predicted_set))
    false_positives = len(predicted_set - gold_set)
    false_negatives = len(gold_set - predicted_set)
    print(f"Wrong: {str(predicted_set - gold_set)}")

    # Calculate precision and recall
    if len(predicted_set) == 1 and len(predicted_set) == 0 and len(gold_set) == 0:
        precision = 1
        recall = 1
    else:
        precision = true_positives / (len(predicted_set)) if (true_positives + false_positives) > 0 else 0
        recall = true_positives / len(gold_set) if (true_positives + false_negatives) > 0 else 0
    return precision, recall

# %%
gold_list = [
    "crm-data/models_triples_json/s03-ima-artists-model.json",
    "crm-data/models_triples_json/s18-s-indianapolis-artists-model.json",
    "crm-data/models_triples_json/s17-s-houston-museum-of-fine-arts-model.json",
    "crm-data/models_triples_json/s10-s-18-artworks-model.json",
    "crm-data/models_triples_json/s27-wildlife-art-model.json",
    "crm-data/models_triples_json/s04-ima-artworks-model.json",
    "crm-data/models_triples_json/s24-s-oakland-museum-paintings-model.json",
    "crm-data/models_triples_json/s19-s-indianapolis-artworks-model.json",
    "crm-data/models_triples_json/s20-s-lacma-model.json",
    "crm-data/models_triples_json/s11-s-19-artists-model.json",
    "crm-data/models_triples_json/s28-gilcrease-model.json",
    "crm-data/models_triples_json/s15-s-detroit-institute-of-art-model.json",
    "crm-data/models_triples_json/s23-s-norton-simon-model.json",
    "crm-data/models_triples_json/s13-s-art-institute-of-chicago-model.json"
]
pre = []
rec = []

# %%
for i, j in enumerate(gold_list):  
    gold_semantics = load_json(j)['semantic_triples']
    predicted_semantics = [i.replace('\'', '').split(", ") for i in step1_list[i][2:-2].split("],\n[")]
    precision, recall = calculate_precision_recall(gold_semantics, predicted_semantics)
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    pre.append(precision)
    rec.append(recall)
print(f"Mean Precision: {sum(pre) / len(pre)}")
print(f"Mean Recall: {sum(rec) / len(rec)}")
# Out:
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# Wrong: {('crm:E52_Time-Span3', 'crm:P82_at_some_time_within', 'artistDeath'), ('crm:E52_Time-Span2', 'crm:P82_at_some_time_within', 'artistBirth'), ('crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'artyear')}
# Precision: 0.7272727272727273
# Recall: 0.6666666666666666
# Wrong: {('crm:E53_Place1', 'crm:P4_has_time-span', 'placeAndDataMade'), ('crm:E22_Man-Made_Object1', 'rdfs:label', 'collectionURL'), ('crm:E55_Type1', 'rdfs:label', 'materials'), ('crm:E13_Attribute_Assignment1', 'crm:P3_has_note', 'inscription'), ('crm:E8_Acquisition1', 'crm:P3_has_note', 'description')}
# Precision: 0.5454545454545454
# Recall: 0.5454545454545454
# Wrong: {('crm:E44_Place_Appellation1', 'rdfs:label', 'makerBioCountry'), ('crm:E78_Collection1', 'crm:P3_has_note', 'collector'), ('crm:E53_Place1', 'crm:P7_took_place_at', 'placeMade'), ('crm:E78_Collection1', 'crm:P3_has_note', 'creditLine'), ('crm:E18_Physical_Thing1', 'crm:P3_has_note', 'materials'), ('crm:E78_Collection1', 'crm:P51_has_former_or_current_owner', 'owner')}
# Precision: 0.5714285714285714
# Recall: 0.5714285714285714
# Wrong: {('crm:E8_Acquisition1', 'crm:P3_has_note', 'galleryLabel'), ('crm:E31_Document1', 'karma:classLink', 'sourceURL'), ('crm:E55_Type2', 'rdfs:label', 'materials')}
# Precision: 0.7692307692307693
# Recall: 0.7692307692307693
# Wrong: {('crm:E55_Type1', 'rdfs:label', 'subtypeOfArt'), ('crm:E33_Linguistic_Object1', 'crm:P3_has_note', 'inscription'), ('crm:E52_Time-Span4', 'crm:P82_at_some_time_within', 'dateMade')}
# Precision: 0.7272727272727273
# Recall: 0.7272727272727273
# Wrong: {('crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'creationDate'), ('crm:E55_Type1', 'rdfs:label', 'materials')}
# Precision: 0.8461538461538461
# Recall: 0.8461538461538461
# Wrong: {('crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'artworkInFocus'), ('crm:E53_Place1', 'rdfs:label', 'residence')}
# Precision: 0.7777777777777778
# Recall: 0.7777777777777778
# Wrong: {('crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'birthDataAndPlace'), ('crm:E35_Title1', 'rdfs:label', 'occupation')}
# Precision: 0.6
# Recall: 0.6
# Wrong: {('crm:E55_Type2', 'rdfs:label', 'medium'), ('crm:E55_Type3', 'rdfs:label', 'culture'), ('crm:E74_Group1', 'rdfs:label', 'attribution'), ('crm:E33_Linguistic_Object1', 'crm:P3_has_note', 'description')}
# Precision: 0.5
# Recall: 0.5
# Wrong: {('crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'date'), ('crm:E55_Type2', 'rdfs:label', 'classification'), ('crm:E39_Actor1', 'rdfs:label', 'name'), ('crm:E55_Type1', 'rdfs:label', 'medium')}
# Precision: 0.6363636363636364
# Recall: 0.5833333333333334
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# Wrong: set()
# Precision: 1.0
# Recall: 1.0
# Mean Precision: 0.7643539000681858
# Mean Recall: 0.7562370169513027

# %%
import re

# Read the file content
with open('gpt-4o-mini-crm/13.txt', 'r') as file:
    content = file.read()

# Use regex to find all <Step2> sections
step2_sections = re.findall(r'<Step2>(.*?)</Step2>', content, re.DOTALL)

# Store the extracted sections in a list
step2_list = [section.strip() for section in step2_sections]

# Print the list to verify
print(step2_list)
# Out:
# ["[['crm:E82_Actor_Appellation1', 'crm:P131_is_identified_by', 'crm:E35_Title1'],\n['crm:E82_Actor_Appellation1', 'crm:P98i_was_born', 'crm:E52_Time-Span1'],\n['crm:E82_Actor_Appellation1', 'crm:P100i_died_in', 'crm:E52_Time-Span2'],\n['crm:E74_Group1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1']]", "[['crm:E82_Actor_Appellation1', 'crm:P131_is_identified_by', 'crm:E35_Title1'],\n['crm:E82_Actor_Appellation1', 'crm:P98i_was_born', 'crm:E52_Time-Span1'],\n['crm:E82_Actor_Appellation1', 'crm:P100i_died_in', 'crm:E52_Time-Span2'],\n['crm:E74_Group1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1']]", "[['crm:E38_Image1', 'crm:P138_represents', 'crm:E22_Man-Made_Object1'],\n['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'],\n['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'],\n['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'],\n['crm:E22_Man-Made_Object1', 'crm:P2_has_type', 'crm:E55_Type1'],\n['crm:E22_Man-Made_Object1', 'crm:P30_transferred_custody_of', 'crm:E8_Acquisition1'],\n['crm:E22_Man-Made_Object1', 'crm:P20_had_specific_purpose', 'crm:E8_Acquisition1'],\n['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E39_Actor1'],\n['crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'],\n['crm:E39_Actor1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'],\n['crm:E39_Actor1', 'crm:P98i_was_born', 'crm:E67_Birth1'],\n['crm:E39_Actor1', 'crm:P100i_died_in', 'crm:E69_Death1'],\n['crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2'],\n['crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span3']]", "[['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'],\n['crm:E13_Attribute_Assignment1', 'crm:P141_assigned', 'crm:E22_Man-Made_Object1'],\n['crm:E8_Acquisition1', 'crm:P22_transferred_title_to', 'crm:E82_Actor_Appellation1'],\n['crm:E8_Acquisition1', 'crm:P2_has_type', 'crm:E55_Type1'],\n['crm:E8_Acquisition1', 'crm:P24_transferred_title_of', 'crm:E35_Title1'],\n['crm:E8_Acquisition1', 'crm:P3_has_note', 'crm:E35_Title1'],\n['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'],\n['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E82_Actor_Appellation1'],\n['crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'],\n['crm:E38_Image1', 'crm:P138_represents', 'crm:E22_Man-Made_Object1'],\n['crm:E82_Actor_Appellation1', 'crm:P1_is_identified_by', 'crm:E35_Title1']]", "[['crm:E55_Type1', 'crm:P2_has_type', 'crm:E22_Man-Made_Object1'],\n['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'],\n['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'],\n['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E39_Actor1'],\n['crm:E39_Actor1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'],\n['crm:E39_Actor1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'],\n['crm:E39_Actor1', 'crm:P100i_died_in', 'crm:E69_Death1'],\n['crm:E22_Man-Made_Object1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'],\n['crm:E22_Man-Made_Object1', 'crm:P24i_changed_ownership_through', 'crm:E8_Acquisition1'],\n['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'crm:E18_Physical_Thing1'],\n['crm:E53_Place1', 'crm:P7_took_place_at', 'crm:E22_Man-Made_Object1'],\n['crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'crm:E78_Collection1'],\n['crm:E78_Collection1', 'crm:P3_has_note', 'crm:E78_Collection1']]", "[['crm:E38_Image1', 'crm:P138_represents', 'crm:E22_Man-Made_Object1'],\n['crm:E22_Man-Made_Object1', 'crm:P102_has_title', 'crm:E35_Title1'],\n['crm:E22_Man-Made_Object1', 'crm:P108i_was_produced_by', 'crm:E12_Production1'],\n['crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E82_Actor_Appellation1'],\n['crm:E8_Acquisition1', 'crm:P4_has_time-span', 'crm:E52_Time-Span3'],\n['crm:E8_Acquisition1', 'crm:P3_has_note', 'crm:E35_Title1'],\n['crm:E22_Man-Made_Object1', 'crm:P74_has_current_or_former_residence', 'crm:E74_Group1'],\n['cr ...

# %%
for i, j in enumerate(gold_list):  
    gold_semantics = load_json(j)['internal_link_triples']
    predicted_semantics = [i.replace('\'', '').split(", ") for i in step2_list[i][2:-2].split("],\n[")]
    precision, recall = calculate_precision_recall(gold_semantics, predicted_semantics)
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    pre.append(precision)
    rec.append(recall)
print(f"Mean Precision: {sum(pre) / len(pre)}")
print(f"Mean Recall: {sum(rec) / len(rec)}")
# Out:
# Wrong: {('crm:E82_Actor_Appellation1', 'crm:P98i_was_born', 'crm:E52_Time-Span1'), ('crm:E74_Group1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'), ('crm:E82_Actor_Appellation1', 'crm:P131_is_identified_by', 'crm:E35_Title1'), ('crm:E82_Actor_Appellation1', 'crm:P100i_died_in', 'crm:E52_Time-Span2')}
# Precision: 0.0
# Recall: 0.0
# Wrong: {('crm:E82_Actor_Appellation1', 'crm:P98i_was_born', 'crm:E52_Time-Span1'), ('crm:E74_Group1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'), ('crm:E82_Actor_Appellation1', 'crm:P131_is_identified_by', 'crm:E35_Title1'), ('crm:E82_Actor_Appellation1', 'crm:P100i_died_in', 'crm:E52_Time-Span2')}
# Precision: 0.0
# Recall: 0.0
# Wrong: {('crm:E39_Actor1', 'crm:P98i_was_born', 'crm:E67_Birth1'), ('crm:E69_Death1', 'crm:P4_has_time-span', 'crm:E52_Time-Span3'), ('crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E39_Actor1'), ('crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'), ('crm:E39_Actor1', 'crm:P100i_died_in', 'crm:E69_Death1'), ('crm:E22_Man-Made_Object1', 'crm:P2_has_type', 'crm:E55_Type1'), ('crm:E67_Birth1', 'crm:P4_has_time-span', 'crm:E52_Time-Span2'), ('crm:E22_Man-Made_Object1', 'crm:P30_transferred_custody_of', 'crm:E8_Acquisition1'), ('crm:E39_Actor1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'), ('crm:E22_Man-Made_Object1', 'crm:P20_had_specific_purpose', 'crm:E8_Acquisition1')}
# Precision: 0.2857142857142857
# Recall: 0.2857142857142857
# Wrong: {('crm:E8_Acquisition1', 'crm:P3_has_note', 'crm:E35_Title1'), ('crm:E82_Actor_Appellation1', 'crm:P1_is_identified_by', 'crm:E35_Title1'), ('crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'), ('crm:E8_Acquisition1', 'crm:P22_transferred_title_to', 'crm:E82_Actor_Appellation1'), ('crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E82_Actor_Appellation1'), ('crm:E8_Acquisition1', 'crm:P2_has_type', 'crm:E55_Type1'), ('crm:E13_Attribute_Assignment1', 'crm:P141_assigned', 'crm:E22_Man-Made_Object1'), ('crm:E8_Acquisition1', 'crm:P24_transferred_title_of', 'crm:E35_Title1')}
# Precision: 0.2727272727272727
# Recall: 0.3
# Wrong: {('crm:E39_Actor1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'), ('crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E39_Actor1'), ('crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'crm:E78_Collection1'), ('crm:E78_Collection1', 'crm:P3_has_note', 'crm:E78_Collection1'), ('crm:E39_Actor1', 'crm:P100i_died_in', 'crm:E69_Death1'), ('crm:E55_Type1', 'crm:P2_has_type', 'crm:E22_Man-Made_Object1'), ('crm:E39_Actor1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'), ('crm:E53_Place1', 'crm:P7_took_place_at', 'crm:E22_Man-Made_Object1'), ('crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'crm:E18_Physical_Thing1')}
# Precision: 0.3076923076923077
# Recall: 0.23529411764705882
# Wrong: {('crm:E8_Acquisition1', 'crm:P4_has_time-span', 'crm:E52_Time-Span3'), ('crm:E8_Acquisition1', 'crm:P3_has_note', 'crm:E35_Title1'), ('crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E82_Actor_Appellation1'), ('crm:E82_Actor_Appellation1', 'crm:P48_has_preferred_identifier', 'crm:E35_Title1'), ('crm:E22_Man-Made_Object1', 'crm:P74_has_current_or_former_residence', 'crm:E74_Group1')}
# Precision: 0.375
# Recall: 0.2
# Wrong: {('crm:E39_Actor1', 'crm:P98i_was_born', 'crm:E67_Birth1'), ('crm:E22_Man-Made_Object1', 'crm:P138_represents', 'crm:E38_Image1'), ('crm:E82_Actor_Appellation1', 'crm:P131_is_identified_by', 'crm:E39_Actor1'), ('crm:E39_Actor1', 'crm:P100i_died_in', 'crm:E69_Death1'), ('crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'credit')}
# Precision: 0.6153846153846154
# Recall: 0.5333333333333333
# Wrong: {('crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'galleryLabel'), ('crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'), ('crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E82_Actor_Appellation1'), ('crm:E52_Time-Span1', 'crm:P82_at_some_time_within', 'crm:E55_Type1'), ('crm:E82_Actor_Appellation1', 'crm:P131_is_identified_by', 'crm:E74_Group1')}
# Precision: 0.5
# Recall: 0.3333333333333333
# Wrong: {('crm:E39_Actor1', 'crm:P98i_was_born', 'crm:E67_Birth1'), ('crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'artworkInFocus'), ('crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E39_Actor1'), ('crm:E82_Actor_Appellation1', 'crm:P131_is_identified_by', 'crm:E39_Actor1'), ('crm:E39_Actor1', 'crm:P100i_died_in', 'crm:E69_Death1'), ('crm:E22_Man-Made_Object1', 'crm:P4_has_time-span', 'crm:E52_Time-Span3'), ('crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'artworkDetails'), ('crm:E39_Actor1', 'crm:P74_has_current_or_former_residence', 'crm:E53_Place1')}
# Precision: 0.2
# Recall: 0.16666666666666666
# Wrong: {('crm:E39_Actor1', 'crm:P2_has_type', 'crm:E35_Title1'), ('crm:E39_Actor1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1')}
# Precision: 0.3333333333333333
# Recall: 0.25
# Wrong: {('crm:E22_Man-Made_Object1', 'crm:P3_has_note', 'crm:E33_Linguistic_Object1'), ('crm:E55_Type1', 'crm:P2_has_type', 'crm:E22_Man-Made_Object1'), ('crm:E22_Man-Made_Object1', 'crm:P14_carried_out_by', 'crm:E74_Group1'), ('crm:E22_Man-Made_Object1', 'crm:P24i_changed_ownership_through', 'crm:E8_Acquisition1')}
# Precision: 0.5
# Recall: 0.4444444444444444
# Wrong: {('crm:E39_Actor1', 'crm:P98i_was_born', 'crm:E67_Birth1'), ('crm:E12_Production1', 'crm:P14_carried_out_by', 'crm:E39_Actor1'), ('crm:E12_Production1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'), ('crm:E39_Actor1', 'crm:P100i_died_in', 'crm:E69_Death1'), ('crm:E39_Actor1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1')}
# Precision: 0.6153846153846154
# Recall: 0.5333333333333333
# Wrong: {('crm:E82_Actor_Appellation1', 'crm:P100i_died_in', 'crm:E52_Time-Span2'), ('crm:E8_Acquisition1', 'crm:P4_has_time-span', 'crm:E52_Time-Span3'), ('crm:E38_Image1', 'crm:P138_represents', 'crm:E82_Actor_Appellation1'), ('crm:E35_Title1', 'crm:P102_has_title', 'crm:E8_Acquisition1'), ('crm:E82_Actor_Appellation1', 'crm:P4_has_time-span', 'crm:E52_Time-Span1'), ('crm:E8_Acquisition1', 'crm:P92_brought_into_existence', 'crm:E82_Actor_Appellation1'), ('crm:E54_Dimension1', 'crm:P43_has_dimension', 'crm:E54_Dimension1'), ('crm:E74_Group1', 'crm:P106_is_composed_of', 'crm:E82_Actor_Appellation1'), ('crm:E82_Actor_Appellation1', 'crm:P131_is_identified_by', 'crm:E74_Group1')}
# Precision: 0.0
# Recall: 0.0
# Wrong: {('crm:E54_Dimension1', 'crm:P43_has_dimension', 'crm:E22_Man-Made_Object1'), ('crm:E8_Acquisition1', 'crm:P3_has_note', 'crm:E35_Title1'), ('crm:E82_Actor_Appellation1', 'crm:P131_is_identified_by', 'crm:E82_Actor_Appellation1'), ('crm:E74_Group1', 'crm:P107_has_current_or_former_member', 'crm:E82_Actor_Appellation1'), ('crm:E82_Actor_Appellation1', 'crm:P131_is_identified_by', 'crm:E74_Group1')}
# Precision: 0.4444444444444444
# Recall: 0.3076923076923077
# Mean Precision: 0.5410941241298385
# Mean Recall: 0.5063260735529643
